# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbolek/learning/blob/master/operanalyst/teorieher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teorie Her

# %% [markdown]
# ## Rozdělení
#
#
# http://euler.fd.cvut.cz/predmety/game_theory/
#
# http://euler.fd.cvut.cz/predmety/teorie_her/

# %% [markdown]
# Podle ceny
# - hry s nulovým součtem
# - hry s nenulovým součtem
#
# Podle vzahu hráčů
# - hry antagonistické
# - hry kooperativní
# - hry proti přírodě
#
# Podle počtu strategií
# - konečné hry
# - nekonečné hry

# %% [markdown]
# ## Maticové hry

# %% [markdown]
# Hra "Kámen-nůžky-papír"
#
# 3 strategie obou hráčů
# - kámen
# - nůžky
# - papír
#
# Výsledek hry
# - kámen vs. kámen = 0
# - kámen vs. nůžky = 1
# - kámen vs. papír = -1
# - nůžky vs. kámen = -1
# - nůžky vs. nůžky = 0
# - nůžky vs. papír = 1
# - papír vs. kámen = 1
# - papír vs. nůžky = -1
# - papír vs. papír = 0
#
# Vyjádřeno v matici výher (odtud maticová hra)
#
# $$H=\begin{pmatrix}
# 0 & 1 & -1 \\
# -1 & 0 & 1 \\
# 1 & -1 & 0
# \end{pmatrix}$$
#
# Strategie hráče A je představena řádky
# $$h_1=\begin{pmatrix}
# 0 & 1 & -1
# \end{pmatrix}$$
# $$h_2=\begin{pmatrix}
# -1 & 0 & 1
# \end{pmatrix}$$
# $$h_3=\begin{pmatrix}
# 1 & -1 & 0
# \end{pmatrix}$$
#
# Strategie hráče B je představena sloupci
# $$g_1=\begin{pmatrix}
# 0 \\
# -1 \\
# 1
# \end{pmatrix}$$
# $$g_2=\begin{pmatrix}
# 1 \\
# 0 \\
# -1
# \end{pmatrix}$$
# $$g_3=\begin{pmatrix}
# -1 \\
# 1 \\
# 0
# \end{pmatrix}$$
#
# matice výher pro hráče B je transponovanou maticí matice výher pro hráče A
# $$G=H^T=\begin{pmatrix}
# 0 & -1 & 1 \\
# 1 & 0 & -1 \\
# -1 & 1 & 0
# \end{pmatrix}$$
#
# Jestliže hráč A volí strategii $i$ a hráč B volí strategii $j$, potom výhra hráče A je dána prvkem $g_{ij}$ a výhra hráče B je dána prvkem $h_{ij}$. Protože $g_{ij} +h_{ij}=0$, klasifikujeme tuto hru jako hru s nulovým součtem.

# %% [markdown]
# ## Čisté strategie

# %% [markdown]
# $$A=\begin{pmatrix}
# 4 & 3 & 2 & 5 \\
# -10 & 2 & 0 & -1 \\
# 7 & 5 & 2 & 3 \\
# 0 & 8  & -4 & -5
# \end{pmatrix}$$
# V jednotlivých řádcích hledáme maximum a z takto získaných maxim vybereme minimum.
# $$\overline v =\min_i \max_j a_{ij}=2$$
# V jednotlivých sloupcích hledáme minimum a z takto získaných minim vybereme maximum.
# $$\underline v = \max_i \min_j a_{ij}=2$$
# Protože
# $$\underline v = \overline v$$
# má hra sedlový bod, cena hry je
# $$v=\underline v = \overline v$$
# a optimální strategie pro prvního hráče je strategie č. 1, alternativně č. 3
# $$\begin{pmatrix}
# 4 & 3 & 2 & 6
# \end{pmatrix}$$
# pro druhého hráče je optimální strategií strategie č. 3
# $$\begin{pmatrix}
# 2 \\
# 0 \\
# 2 \\
# -4
# \end{pmatrix}$$

# %% [markdown]
# $$A=\begin{pmatrix}
# 5 & 1 \\
# 3 & 4
# \end{pmatrix}$$
#
# $$\overline v=\min_i \max_j a_{ij}=4$$
# $$\underline v = \max_i \min_j a_{ij}=3$$
#
# Hra nemá sedlový bod a nemá řešení v čistých strategiích.

# %% [markdown]
# ## Smíšené strategie

# %% [markdown]
# ### Optimální řešení ve smíšených strategiích

# %% [markdown]
# Hráč A volí smíšenou strategii $s^A=(s_1^A, s_2^A, ..., s_n^A)$. Hráč B volí smíšenou strategii $s^B=(s_1^B, s_2^B, ..., s_n^B)$.
#
#
# $$max\{v:A^Ts^A- \begin{pmatrix}v \\
# v \\
# \vdots \\
# v
# \end{pmatrix} \ge 0, \sum_{i=1}^ns_i^A=1,s^A \ge 0, v \in R\}$$
#
# $$min\{w:As^B- \begin{pmatrix}w \\
# w \\
# \vdots \\
# w
# \end{pmatrix} \le 0, \sum_{i=1}^ns_i^B=1,s^B \ge 0, w \in R\}$$

# %% [markdown]
# ### Příklad

# %% [markdown]
# Vyřešte hru kámen-nůžky-papír
#
# $$H=\begin{pmatrix}
# 0 & 1 & -1 \\
# -1 & 0 & 1 \\
# 1 & -1 & 0
# \end{pmatrix}$$
#
# $$f(s^A)=v \to max$$
#
# $$\begin{matrix}
#  & -s_2^A & +s_3^A & -v & \ge & 0 \\
#  s_1^A & & -s_3^A & -v & \ge & 0 \\
#  -s_1^A & +s_2^A & & -v & \ge & 0 \\
#  s_1^A & +s_2^A & +s_3^A & &=& 1
# \end{matrix}
# $$
#
#
# $$g(s^B)=w \to min$$
#
# $$\begin{matrix}
#  & s_2^B & -s_3^B & -w & \le & 0 \\
#  -s_1^B & & +s_3^B & -w & \le & 0 \\
#  s_1^B & -s_2^B & & -w & \le & 0 \\
#  s_1^B & +s_2^B & +s_3^B & &=& 1
# \end{matrix}
# $$

# %% [markdown]
# ### Řešení

# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: amply>=0.1.2 in /usr/local/lib/python3.6/dist-packages (from pulp) (0.1.4)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.6/dist-packages (from amply>=0.1.2->pulp) (0.16)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from amply>=0.1.2->pulp) (2.4.7)

# %%
from pulp import *
probA = LpProblem("Game", LpMaximize)
sA1 = LpVariable("sA1", 0, 1000)
sA2 = LpVariable("sA2", 0, 1000)
sA3 = LpVariable("sA3", 0, 1000)
v = LpVariable("v", 0, 1000)
probA += (-sA2+sA3-v >= 0)
probA += (sA1-sA3-v >= 0)
probA += (-sA1+sA2-v >= 0)
probA += (sA1+sA2+sA3 == 1)
probA += (v)
status = probA.solve()

print(f'sA1={value(sA1)}, sA2={value(sA2)}, sA3={value(sA3)}, v={value(v)}')
print(LpStatus[status])
# Out:
# sA1=0.33333333, sA2=0.33333333, sA3=0.33333333, v=0.0
# Optimal

# %%
from pulp import *
prob = LpProblem("Game", LpMaximize)
x1 = LpVariable("x1", 0, 1000)
x2 = LpVariable("x2", 0, 1000)
x3 = LpVariable("x3", 0, 1000)
prob += (x2 -x3 <= 1)
prob += (-x1+x3 <= 1)
prob += (x1-x2 <= 1)
prob += (x1 + x2 + x3)
status = prob.solve()

print(f'x1={value(x1)}, x2={value(x2)} , x3={value(x3)}')
print(LpStatus[status])
# Out:
# x1=1000.0, x2=1000.0 , x3=1000.0
# Optimal

# %%
from pulp import *
prob = LpProblem("Game", LpMaximize)
x1 = LpVariable("x1", 0, 1000)
x2 = LpVariable("x2", 0, 1000)
x3 = LpVariable("x3", 0, 1000)
prob += (3*x2 +x3 <= 1)
prob += (x1+3*x3 <= 1)
prob += (3*x1+x2 <= 1)
prob += (x1 + x2 + x3)
status = prob.solve()

print(f'x1={value(x1)}, x2={value(x2)} , x3={value(x3)}')
print(LpStatus[status])
# Out:
# x1=0.25, x2=0.25 , x3=0.25
# Optimal

# %%
from pulp import *
prob = LpProblem("Game", LpMinimize)
x1 = LpVariable("x1", 0, 1000)
x2 = LpVariable("x2", 0, 1000)
x3 = LpVariable("x3", 0, 1000)
prob += (x2 -x3 >= 1)
prob += (-x1+x3 >= 1)
prob += (x1-x2 >= 1)
prob += (x1 + x2 + x3)
status = prob.solve()

print(f'x1={value(x1)}, x2={value(x2)} , x3={value(x3)}')
print(LpStatus[status])
# Out:
# x1=1.0, x2=0.0 , x3=2.0
# Infeasible

# %%
from pulp import *
prob = LpProblem("Game", LpMinimize)
x1 = LpVariable("x1", 0, 1000)
x2 = LpVariable("x2", 0, 1000)
x3 = LpVariable("x3", 0, 1000)
v = LpVariable("v", 0, 1000)
prob += (x2 -x3-v <= 0)
prob += (-x1+x3-v <= 0)
prob += (x1-x2-v <= 0)
prob += (x1+x2+x3 == 1)
prob += (v)
status = prob.solve()

print(f'x1={value(x1)}, x2={value(x2)}, x3={value(x3)}, v={value(v)}')
print(LpStatus[status])
# Out:
# x1=0.33333333, x2=0.33333333, x3=0.33333333, v=0.0
# Optimal

# %% [markdown]
# ### Řešení iteracemi

# %%
from random import random as rnd
H = [[0, 1, -1], [-1, 0, 1], [1, -1, 0]]
G = [[0, -1, 1], [1, 0, -1], [-1, 1, 0]]
volbyA = [1] * len(H)
pocetVolebA = 0
volbyB = [1] * len(G)
pocetVolebB = 0

def volba(hra, volby):
  volbyCelkem = sum(volby)
  pravdepodobnosti = [volba / volbyCelkem for volba in volby]
  strategie = [[p * v for p, v in zip(volby, radek)] for radek in hra]

  minIndex  = 0
  minHodnota = strategie[minIndex]
  for index, hodnota in enumerate(strategie):
    if hodnota < minHodnota:
      minHodnota = minHodnota
      minIndex = index
  return minHodnota, minIndex

volbaA = 2
for step in range(1000):
  vyhraB, volbaB = volba(H, volbyA)
  vyhraA, volbaA = volba(G, volbyB)
  volbyA[volbaA] += 1
  volbyB[volbaB] += 1
  print(step, '\t', volbaA, *volbyA, '\t', volbaB, *volbyB, sep='\t')
# Out:
# 0			2	1	1	2			1	1	2	1
# 1			2	1	1	3			1	1	3	1
# 2			2	1	1	4			1	1	4	1
# 937			2	1	1	939			1	1	939	1
# 938			2	1	1	940			1	1	940	1
# 939			2	1	1	941			1	1	941	1
# 940			2	1	1	942			1	1	942	1
# 941			2	1	1	943			1	1	943	1
# 942			2	1	1	944			1	1	944	1
# 943			2	1	1	945			1	1	945	1
# 944			2	1	1	946			1	1	946	1
# 945			2	1	1	947			1	1	947	1
# 946			2	1	1	948			1	1	948	1
# 947			2	1	1	949			1	1	949	1
# 948			2	1	1	950			1	1	950	1
# 949			2	1	1	951			1	1	951	1
# 950			2	1	1	952			1	1	952	1
# 951			2	1	1	953			1	1	953	1
# 952			2	1	1	954			1	1	954	1
# 953			2	1	1	955			1	1	955	1
# 954			2	1	1	956			1	1	956	1
# 955			2	1	1	957			1	1	957	1
# 956			2	1	1	958			1	1	958	1
# 957			2	1	1	959			1	1	959	1
# 958			2	1	1	960			1	1	960	1
# 959			2	1	1	961			1	1	961	1
# 960			2	1	1	962			1	1	962	1
# 961			2	1	1	963			1	1	963	1
# 962			2	1	1	964			1	1	964	1
# 963			2	1	1	965			1	1	965	1
# 964			2	1	1	966			1	1	966	1
# 965			2	1	1	967			1	1	967	1
# 966			2	1	1	968			1	1	968	1
# 967			2	1	1	969			1	1	969	1
# 968			2	1	1	970			1	1	970	1
# 969			2	1	1	971			1	1	971	1
# 970			2	1	1	972			1	1	972	1
# 971			2	1	1	973			1	1	973	1
# 972			2	1	1	974			1	1	974	1
# 973			2	1	1	975			1	1	975	1
# 974			2	1	1	976			1	1	976	1
# 975			2	1	1	977			1	1	977	1
# 976			2	1	1	978			1	1	978	1
# 977			2	1	1	979			1	1	979	1
# 978			2	1	1	980			1	1	980	1
# 979			2	1	1	981			1	1	981	1
# 980			2	1	1	982			1	1	982	1
# 981			2	1	1	983			1	1	983	1
# 982			2	1	1	984			1	1	984	1
# 983			2	1	1	985			1	1	985	1
# 984			2	1	1	986			1	1	986	1
# 985			2	1	1	987			1	1	987	1
# 986			2	1	1	988			1	1	988	1
# 987			2	1	1	989			1	1	989	1
# 988			2	1	1	990			1	1	990	1
# 989			2	1	1	991			1	1	991	1
# 990			2	1	1	992			1	1	992	1
# 991			2	1	1	993			1	1	993	1
# 992			2	1	1	994			1	1	994	1
# 993			2	1	1	995			1	1	995	1
# 994			2	1	1	996			1	1	996	1
# 995			2	1	1	997			1	1	997	1
# 996			2	1	1	998			1	1	998	1
# 997			2	1	1	999			1	1	999	1
# 998			2	1	1	1000			1	1	1000	1
# 999			2	1	1	1001			1	1	1001	1

# %% [markdown]
# ### Normalizace strategie

# %% [markdown]
# Postup, při kterém z četností vypočítáme pravděpodobnosti.

# %%
def normalizeStrategy(strategy):
  s = sum(strategy)
  result = []
  for p in strategy:
    result.append(p / s)
  return result

def normalizeStrategy(strategy):
  s = sum(strategy)
  result = [p / s for p in strategy]
  return result

# %% [markdown]
# ### Výstup informace o hře, včetně smíšených strategií

# %%
def printGame(strategies, gameMatrices):
  strategyA = normalizeStrategy(strategies[0])
  strategyB = normalizeStrategy(strategies[1])
  gameA = gameMatrices[0]
  gameB = gameMatrices[1]

  print('\t', end='')
  for item in strategyB:
    print(f'{item:.2f}\t', end='')
  print()
  for index, value in enumerate(strategyA):
    print(f'{value:.2f}\t', end='')
    for mItem in gameA[index]:
      print(f'{mItem}\t', end='')
    print()

# %% [markdown]
# ### Kroky při iterativním výpočtu

# %%
def playerAStep(mixedStrategy, gameMatrix):
  costs = [0] * len(gameMatrix[0])
  for pureStrategy, row in zip(mixedStrategy, gameMatrix):
    for index, hItem in enumerate(row):
      costs[index] += pureStrategy * hItem
  
  maxIndex = 0
  maxValue = costs[0]
  for index, cost in enumerate(costs):
    if cost > maxValue:
      maxValue = cost
      maxIndex = index
  
  return maxIndex

# %%
def playerBStep(mixedStrategy, gameMatrix):
  costs = [0] * len(gameMatrix[0])
  for pureStrategy, row in zip(mixedStrategy, gameMatrix):
    for index, hItem in enumerate(row):
      costs[index] += pureStrategy * hItem
  
  minIndex = 0
  minValue = costs[0]
  for index, cost in enumerate(costs):
    if cost < minValue:
      minValue = cost
      minIndex = index
  
  return minIndex

# %%
def gameStep(strategies, gameMatrices):
  strategyA = [*strategies[0]]
  strategyB = [*strategies[1]]
  gameA = gameMatrices[0]
  gameB = gameMatrices[1]

  pureStrategyB = playerBStep(strategyA, gameA)
  strategyB[pureStrategyB] += 1

  pureStrategyA = playerAStep(strategyB, gameB)
  strategyA[pureStrategyA] += 1

  return strategyA, strategyB

# %% [markdown]
# ### Řešení hry

# %%
H = [[0, 1, -1], [-1, 0, 1], [1, -1, 0]]
G = [[0, -1, 1], [1, 0, -1], [-1, 1, 0]]

strategyA = [1, 0, 0]
strategyB = [1, 0, 0]
for index in range(10000):
  strategyA, strategyB = gameStep((strategyA, strategyB), (H, G))
  if index % 1000 == 0:
    printGame((strategyA, strategyB), (H, G))
    print('-'*30)
    #print(normalizeStrategy(strategyA), normalizeStrategy(strategyB))
# Out:
# 	0.50	0.00	0.50
# 0.50	0	1	-1
# 0.00	-1	0	1
# 0.50	1	-1	0
# ------------------------------
# 	0.33	0.34	0.33
# 0.35	0	1	-1
# 0.32	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.32	0.33	0.34
# 0.34	0	1	-1
# 0.34	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.33	0.34	0.33
# 0.34	0	1	-1
# 0.33	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.33	0.34	0.33
# 0.34	0	1	-1
# 0.33	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.34	0.33	0.33
# 0.33	0	1	-1
# 0.34	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.34	0.33	0.33
# 0.33	0	1	-1
# 0.33	-1	0	1
# 0.34	1	-1	0
# ------------------------------
# 	0.34	0.33	0.33
# 0.33	0	1	-1
# 0.33	-1	0	1
# 0.34	1	-1	0
# ------------------------------
# 	0.33	0.33	0.34
# 0.33	0	1	-1
# 0.34	-1	0	1
# 0.33	1	-1	0
# ------------------------------
# 	0.33	0.34	0.33
# 0.33	0	1	-1
# 0.33	-1	0	1
# 0.34	1	-1	0
# ------------------------------
