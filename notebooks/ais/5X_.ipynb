# %%
# !pip install graphviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 156.9 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import graphviz
dot_data = '''
digraph {
    A -> B;
    A -> C;
    B -> D;
    C -> D;
}
'''
graph = graphviz.Source(dot_data)
graph
