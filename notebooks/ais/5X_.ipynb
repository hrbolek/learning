# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 156.9 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %%
import graphviz
dot_data = '''
digraph {
    rankdir="LR"
    label="Regresion Neural Network"
    
    Bias1 [label="Bias"];
    Bias2 [label="Bias"];
    Result [label="Max Face\nAmout", shape=box];
    Age [shape=box];
    Income [shape=box];
    Weight [shape=box];
    HDL [shape=box];
    LDL [shape=box];
    TGL [shape=box];
    Bias1 -> H1;
    Age -> H1;
    Income -> H1;
    Weight -> H1;
    HDL -> H1;
    LDL -> H1;
    TGL -> H1;
    Age -> H2;
    Income -> H2;
    Weight -> H2;
    HDL -> H2;
    LDL -> H2;
    TGL -> H2;
    Age -> H3;
    Income -> H3;
    Weight -> H3;
    HDL -> H3;
    LDL -> H3;
    TGL -> H3;
    Age -> H4;
    Income -> H4;
    Weight -> H4;
    HDL -> H4;
    LDL -> H4;
    TGL -> H4;
    Bias2 -> Result;
    H1 -> Result;
    H2 -> Result;
    H3 -> Result;
    H4 -> Result;
    subgraph cluster_1 {
        Bias1;
        Age;
        Income;
        Weight;
        HDL;
        LDL;
        TGL;
        label = "Input\nFeatures";
        color=white
        fontcolor=red
    }
    subgraph cluster_2 {
        Bias2;
        H1;
        H2;
        H3;
        H4;
        label = "Hidden";
        color=white
        height=50
        fontcolor=red
    }
    subgraph cluster_3 {
        Result;
        label = "Output";
        color=white
        fontcolor=red
    }
}
'''
graph = graphviz.Source(dot_data)
graph

# %%
import graphviz
dot_data = '''
digraph {
    rankdir="LR"
    ranksep=1
    label="Classification Neural Network"
    Bias1 [label="Bias"];
    Bias2 [label="Bias"];
    Age [shape=box];
    Income [shape=box];
    Weight [shape=box];
    HDL [shape=box];
    LDL [shape=box];
    TGL [shape=box];
    Bias1 -> H1;
    Age -> H1;
    Income -> H1;
    Weight -> H1;
    HDL -> H1;
    LDL -> H1;
    TGL -> H1;
    Age -> H2;
    Income -> H2;
    Weight -> H2;
    HDL -> H2;
    LDL -> H2;
    TGL -> H2;
    Age -> H3;
    Income -> H3;
    Weight -> H3;
    HDL -> H3;
    LDL -> H3;
    TGL -> H3;
    Age -> H4;
    Income -> H4;
    Weight -> H4;
    HDL -> H4;
    LDL -> H4;
    TGL -> H4;
    
    Bias2 -> Preferred;
    Bias2 -> Standard;
    Bias2 -> Substandard;
    Bias2 -> Decline;
    H1 -> Preferred;
    H1 -> Standard;
    H1 -> Substandard;
    H1 -> Decline;
    H2 -> Preferred;
    H2 -> Standard;
    H2 -> Substandard;
    H2 -> Decline;
    H3 -> Preferred;
    H3 -> Standard;
    H3 -> Substandard;
    H3 -> Decline;
    H4 -> Preferred;
    H4 -> Standard;
    H4 -> Substandard;
    H4 -> Decline;
    
    subgraph cluster_1 {
        Bias1;
        Age;
        Income;
        Weight;
        HDL;
        LDL;
        TGL;
        label = "Input\nFeatures";
        color=white
        fontcolor=red
    }
    subgraph cluster_2 {
        Bias2;
        H1;
        H2;
        H3;
        H4;
        label = "Hidden";
        color=white
        fontcolor=red
    }
    subgraph cluster_3 {
        Preferred [shape=box];
        Standard [shape=box];
        Substandard [shape=box];
        Decline [shape=box];
        label = "Output";
        color=white
        fontcolor=red
    }
}
'''
graph = graphviz.Source(dot_data)
graph

# %%
import graphviz
dot_data = '''
digraph {
    label="Neuron Model"
    ranksep=0
    Input1 [shape="circle", style="dashed"];
    Input2 [shape="circle", style="dashed"];
    Input3 [shape="circle", style="dashed"];
    Neuron [shape="circle"];
    AFunc [label="Activation function", shape="box"];
    Output [shape="circle", style="dashed"];
    Input1 -> Neuron [label="weight 1"];
    Input2 -> Neuron [label="weight 2"];
    Input3 -> Neuron [label="weight 3"];

    Neuron -> AFunc;
    AFunc -> Output;
}
'''
graph = graphviz.Source(dot_data)
graph

# %%
import graphviz
dot_data = '''
digraph {
    label=""
    ranksep=1
    rankdir="TB"
    layout = dot
    
    subgraph cluster_1 {
        rank = same;
        label="Input Layer"
        fontname="times-bold"
        labeljust = r
        labelangle=180
        color="white"
        Input1 [shape="circle", style="dashed", label="I1"];
        Input2 [shape="circle", style="dashed", label="I2"];
        Bias1 [shape="circle", style="dashed", label="B1"];
        subgraph cluster_1a {
            label="Input Layer"
        }
    }
    subgraph cluster_2 {
        rank = same;
        label="Hidden Layer 1"
        fontname="times-bold"
        labeljust = l
        color="white"
        Neuron11 [shape="circle", label="N2"];
        Neuron12 [shape="circle", label="N1"];
        Bias2 [shape="circle", style="dashed", label="B2"];
    }
    subgraph cluster_3 {
        rank = same;
        label="Hidden Layer 2"
        labeljust = l
        fontname="times-bold"
        color="white"
        Neuron21 [shape="circle", label="N3"];
        Neuron22 [shape="circle", label="N4"];
        Bias3 [shape="circle", style="dashed", label="B3"];
    }
    subgraph cluster_4 {
        rank = same;
        label="Output Layer"
        fontname="times-bold"
        labeljust = l
        color="white"
        Output [shape="circle", style="dashed", label="O "];
    }
    
    
    Bias1 -> Neuron11;
    Bias1 -> Neuron12;
    Bias1 -> Bias2 [color="white"];
    Input1 -> Neuron11;
    Input1 -> Neuron12;
    Input2 -> Neuron11;
    Input2 -> Neuron12;
    
    Bias2 -> Neuron21;
    Bias2 -> Neuron22;
    Bias2 -> Bias3 [color="white"];
    Neuron11 -> Neuron21;
    Neuron11 -> Neuron22;
    Neuron12 -> Neuron21;
    Neuron12 -> Neuron22;
    
    Bias3 -> Output;
    Neuron21 -> Output;
    Neuron22 -> Output;

}
'''
graph = graphviz.Source(dot_data)
graph

# %%
import graphviz
dot_data = '''
digraph {
    label=""
    ranksep=1
    rankdir="TB"
    layout = dot
    
    subgraph cluster_1 {
        rank = same;
        label="Input Layer"
        fontname="times-bold"
        labeljust = r
        labelangle=180
        color="white"
        Input1 [shape="circle", style="dashed", label="I1"];
        Input2 [shape="circle", style="dashed", label="I2"];
        Bias1 [shape="circle", style="dashed", label="B1"];
        subgraph cluster_1a {
            label="Input Layer"
        }
    }
    subgraph cluster_2 {
        rank = same;
        label="Hidden Layer 1"
        fontname="times-bold"
        labeljust = l
        color="white"
        Neuron11 [shape="circle", label="N2"];
        Neuron12 [shape="circle", label="N1"];
        Bias2 [shape="circle", style="dashed", label="B2"];
    }
    subgraph cluster_3 {
        rank = same;
        label="Hidden Layer 2"
        labeljust = l
        fontname="times-bold"
        color="white"
        Neuron21 [shape="circle", label="N3"];
        Neuron22 [shape="circle", label="N4"];
        Bias3 [shape="circle", style="dashed", label="B3"];
    }
    subgraph cluster_4 {
        rank = same;
        label="Output Layer"
        fontname="times-bold"
        labeljust = l
        color="white"
        Output [shape="circle", style="dashed", label="O "];
    }
    
    
    Bias1 -> Neuron11;
    Bias1 -> Neuron12;
    Bias1 -> Bias2 [color="white"];
    Input1 -> Neuron11;
    Input1 -> Neuron12;
    Input2 -> Neuron11;
    Input2 -> Neuron12;
    
    Bias2 -> Neuron21;
    Bias2 -> Neuron22;
    Bias2 -> Bias3 [color="white"];
    Neuron11 -> Neuron21;
    Neuron11 -> Neuron22;
    Neuron12 -> Neuron21;
    Neuron12 -> Neuron22;
    
    Bias3 -> Output;
    Neuron21 -> Output;
    Neuron22 -> Output;

}
'''
graph = graphviz.Source(dot_data)
graph
graphviz.pipe_string('dot', 'svg', dot_data, encoding='ascii')
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Generated by graphviz version 2.43.0 (0)\n -->\n<!-- Title: %3 Pages: 1 -->\n<svg width="203pt" height="445pt"\n viewBox="0.00 0.00 203.00 445.39" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 441.39)">\n<title>%3</title>\n<polygon fill="white" stroke="transparent" points="-4,4 -4,-441.39 199,-441.39 199,4 -4,4"/>\n<g id="clust1" class="cluster">\n<title>cluster_1</title>\n<polygon fill="none" stroke="white" points="18,-348.79 18,-429.39 184,-429.39 184,-348.79 18,-348.79"/>\n<text text-anchor="middle" x="140.5" y="-414.19" font-family="Times,serif" font-weight="bold" font-size="14.00">Input Layer</text>\n</g>\n<g id="clust3" class="cluster">\n<title>cluster_2</title>\n<polygon fill="none" stroke="white" points="8,-233.89 8,-315.79 187,-315.79 187,-233.89 8,-233.89"/>\n<text text-anchor="middle" x="62.5" y="-300.59" font-family="Times,serif" font-weight="bold" font-size="14.00">Hidden Layer 1</text>\n</g>\n<g id="clust4" class="cluster">\n<title>cluster_3</title>\n<polygon fill="none" stroke="white" points="8,-119 8,-200.89 187,-200.89 187,-119 8,-119"/>\n<text text-anchor="middle" x="62.5" y="-185.69" font-family="Times,serif" font-weight="bold" font-size="14.00">Hidden Layer 2</text>\n</g>\n<g id="clust5" class="cluster">\n<title>cluster_4</title>\n<polygon fill="none" stroke="white" points="48,-8 48,-86 146,-86 146,-8 48,-8"/>\n<text text-anchor="middle" x="97" y="-70.8" font-family="Times,serif" font-weight="bold" font-size="14.00">Output Layer</text>\n</g>\n<!-- Input1 -->\n<g id="node1" class="node">\n<title>Input1</title>\n<ellipse fill="none" stroke="black" stroke-dasharray="5,2" cx="158" cy="-377.59" rx="18.4" ry="18.4"/>\n<text text-anchor="middle" x="158" y="-373.89" font-family="Times,serif" font-size="14.00">I1</text>\n</g>\n<!-- Neuron11 -->\n<g id="node4" class="node">\n<title>Neuron11</title>\n<ellipse fill="none" stroke="black" cx="158" cy="-263.34" rx="21.4" ry="21.4"/>\n<text text-anchor="middle" x="158" y="-259.64" font-family="Times,serif" font-size="14.00">N2</text>\n</g>\n<!-- Input1&#45;&gt;Neuron11 -->\n<g id="edge4" class="edge">\n<title>Input1&#45;&gt;Neuron11</title>\n<path fill="none" stroke="black" d="M158,-359.05C158,-341.93 158,-315.53 158,-294.95"/>\n<polygon fill="black" stroke="black" points="161.5,-294.8 158,-284.8 154.5,-294.8 161.5,-294.8"/>\n</g>\n<!-- Neuron12 -->\n<g id="node5" class="node">\n<title>Neuron12</title>\n<ellipse fill="none" stroke="black" cx="97" cy="-263.34" rx="21.4" ry="21.4"/>\n<text text-anchor="middle" x="97" y="-259.64" font-family="Times,serif" font-size="14.00">N1</text>\n</g>\n<!-- Input1&#45;&gt;Neuron12 -->\n<g id="edge5" class="edge">\n<title>Input1&#45;&gt;Neuron12</title>\n<path fill="none" stroke="black" d="M149.52,-360.98C139.77,-343.03 123.58,-313.25 111.75,-291.49"/>\n<polygon fill="black" stroke="black" points="114.67,-289.53 106.82,-282.41 108.52,-292.87 114.67,-289.53"/>\n</g>\n<!-- Input2 -->\n<g id="node2" class="node">\n<title>Input2</title>\n<ellipse fill="none" stroke="black" stroke-dasharray="5,2" cx="104" cy="-377.59" rx="18.4" ry="18.4"/>\n<text text-anchor="middle" x="104" y="-373.89" font-family="Times,serif" font-size="14.00">I2</text>\n</g>\n<!-- Input2&#45;&gt;Neuron11 -->\n<g id="edge6" class="edge">\n<title>Input2&#45;&gt;Neuron11</title>\n<path fill="none" stroke="black" d="M111.51,-360.98C120.04,-343.24 134.13,-313.95 144.57,-292.25"/>\n<polygon fill="black" stroke="black" points="147.75,-293.71 148.93,-283.18 141.45,-290.68 147.75,-293.71"/>\n</g>\n<!-- Input2&#45;&gt;Neuron12 -->\n<g id="edge7" class="edge">\n<title>Input2&#45;&gt;Neuron12</title>\n<path fill="none" stroke="black" d="M102.91,-359.05C101.84,-341.93 100.19,-315.53 98.91,-294.95"/>\n<polygon fill="black ...

# %%
from IPython.display import SVG
import graphviz
dot_data = '''
digraph {
    label=""
    ranksep=1
    rankdir="TB"
    layout = dot
    
    subgraph cluster_1 {
        rank = same;
        label="Input Layer"
        fontname="times-bold"
        labeljust = r
        labelangle=180
        color="white"
        Input1 [shape="circle", style="dashed", label="I1"];
        Input2 [shape="circle", style="dashed", label="I2"];
        Bias1 [shape="circle", style="dashed", label="B1"];
        subgraph cluster_1a {
            label="Input Layer"
        }
    }
    subgraph cluster_2 {
        rank = same;
        label="Hidden Layer 1"
        fontname="times-bold"
        labeljust = l
        color="white"
        Neuron11 [shape="circle", label="N2"];
        Neuron12 [shape="circle", label="N1"];
        Bias2 [shape="circle", style="dashed", label="B2"];
    }
    subgraph cluster_3 {
        rank = same;
        label="Hidden Layer 2"
        labeljust = l
        fontname="times-bold"
        color="white"
        Neuron21 [shape="circle", label="N3"];
        Neuron22 [shape="circle", label="N4"];
        Bias3 [shape="circle", style="dashed", label="B3"];
    }
    subgraph cluster_4 {
        rank = same;
        label="Output Layer"
        fontname="times-bold"
        labeljust = l
        color="white"
        Output [shape="circle", style="dashed", label="O "];
    }
    
    
    Bias1 -> Neuron11;
    Bias1 -> Neuron12;
    Bias1 -> Bias2 [color="white"];
    Input1 -> Neuron11;
    Input1 -> Neuron12;
    Input2 -> Neuron11;
    Input2 -> Neuron12;
    
    Bias2 -> Neuron21;
    Bias2 -> Neuron22;
    Bias2 -> Bias3 [color="white"];
    Neuron11 -> Neuron21;
    Neuron11 -> Neuron22;
    Neuron12 -> Neuron21;
    Neuron12 -> Neuron22;
    
    Bias3 -> Output;
    Neuron21 -> Output;
    Neuron22 -> Output;

}
'''
SVG(graphviz.pipe_string('dot', 'svg', dot_data, encoding='ascii'))

# %%
from IPython.display import JSON

data = [{"name": "name", "surname": "surname"}, {"name": "name", "surname": "surname"}]
JSON(data)
