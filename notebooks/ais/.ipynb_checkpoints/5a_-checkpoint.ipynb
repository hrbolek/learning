# %% [markdown]
# https://github.com/jeffheaton/app_deep_learning/blob/main/t81_558_class_03_4_early_stop.ipynb

# %%
import torch

try:
    import google.colab

    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Make use of a GPU or MPS (Apple) if one is available.  (see module 3.2)
device = (
    "mps"
    if getattr(torch, "has_mps", False)
    else "cuda"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Note: not using Google CoLab
# Using device: cpu

# %% [markdown]
# ## Iris dataset

# %%
from sklearn import datasets

iris = datasets.load_iris()
print(iris.keys())
print(iris.DESCR)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
def namedata(data):
    return {
        'sepal_l': data[0],
        'sepal_w': data[1],
        'petal_l': data[2],
        'petal_w': data[3]
    }

table = list(map(namedata, iris.data))
table
# Out:
# [{'sepal_l': 5.1, 'sepal_w': 3.5, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 4.9, 'sepal_w': 3.0, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 4.7, 'sepal_w': 3.2, 'petal_l': 1.3, 'petal_w': 0.2},
#  {'sepal_l': 4.6, 'sepal_w': 3.1, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.6, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 5.4, 'sepal_w': 3.9, 'petal_l': 1.7, 'petal_w': 0.4},
#  {'sepal_l': 4.6, 'sepal_w': 3.4, 'petal_l': 1.4, 'petal_w': 0.3},
#  {'sepal_l': 5.0, 'sepal_w': 3.4, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 4.4, 'sepal_w': 2.9, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 4.9, 'sepal_w': 3.1, 'petal_l': 1.5, 'petal_w': 0.1},
#  {'sepal_l': 5.4, 'sepal_w': 3.7, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 4.8, 'sepal_w': 3.4, 'petal_l': 1.6, 'petal_w': 0.2},
#  {'sepal_l': 4.8, 'sepal_w': 3.0, 'petal_l': 1.4, 'petal_w': 0.1},
#  {'sepal_l': 4.3, 'sepal_w': 3.0, 'petal_l': 1.1, 'petal_w': 0.1},
#  {'sepal_l': 5.8, 'sepal_w': 4.0, 'petal_l': 1.2, 'petal_w': 0.2},
#  {'sepal_l': 5.7, 'sepal_w': 4.4, 'petal_l': 1.5, 'petal_w': 0.4},
#  {'sepal_l': 5.4, 'sepal_w': 3.9, 'petal_l': 1.3, 'petal_w': 0.4},
#  {'sepal_l': 5.1, 'sepal_w': 3.5, 'petal_l': 1.4, 'petal_w': 0.3},
#  {'sepal_l': 5.7, 'sepal_w': 3.8, 'petal_l': 1.7, 'petal_w': 0.3},
#  {'sepal_l': 5.1, 'sepal_w': 3.8, 'petal_l': 1.5, 'petal_w': 0.3},
#  {'sepal_l': 5.4, 'sepal_w': 3.4, 'petal_l': 1.7, 'petal_w': 0.2},
#  {'sepal_l': 5.1, 'sepal_w': 3.7, 'petal_l': 1.5, 'petal_w': 0.4},
#  {'sepal_l': 4.6, 'sepal_w': 3.6, 'petal_l': 1.0, 'petal_w': 0.2},
#  {'sepal_l': 5.1, 'sepal_w': 3.3, 'petal_l': 1.7, 'petal_w': 0.5},
#  {'sepal_l': 4.8, 'sepal_w': 3.4, 'petal_l': 1.9, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.0, 'petal_l': 1.6, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.4, 'petal_l': 1.6, 'petal_w': 0.4},
#  {'sepal_l': 5.2, 'sepal_w': 3.5, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 5.2, 'sepal_w': 3.4, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 4.7, 'sepal_w': 3.2, 'petal_l': 1.6, 'petal_w': 0.2},
#  {'sepal_l': 4.8, 'sepal_w': 3.1, 'petal_l': 1.6, 'petal_w': 0.2},
#  {'sepal_l': 5.4, 'sepal_w': 3.4, 'petal_l': 1.5, 'petal_w': 0.4},
#  {'sepal_l': 5.2, 'sepal_w': 4.1, 'petal_l': 1.5, 'petal_w': 0.1},
#  {'sepal_l': 5.5, 'sepal_w': 4.2, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 4.9, 'sepal_w': 3.1, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.2, 'petal_l': 1.2, 'petal_w': 0.2},
#  {'sepal_l': 5.5, 'sepal_w': 3.5, 'petal_l': 1.3, 'petal_w': 0.2},
#  {'sepal_l': 4.9, 'sepal_w': 3.6, 'petal_l': 1.4, 'petal_w': 0.1},
#  {'sepal_l': 4.4, 'sepal_w': 3.0, 'petal_l': 1.3, 'petal_w': 0.2},
#  {'sepal_l': 5.1, 'sepal_w': 3.4, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.5, 'petal_l': 1.3, 'petal_w': 0.3},
#  {'sepal_l': 4.5, 'sepal_w': 2.3, 'petal_l': 1.3, 'petal_w': 0.3},
#  {'sepal_l': 4.4, 'sepal_w': 3.2, 'petal_l': 1.3, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.5, 'petal_l': 1.6, 'petal_w': 0.6},
#  {'sepal_l': 5.1, 'sepal_w': 3.8, 'petal_l': 1.9, 'petal_w': 0.4},
#  {'sepal_l': 4.8, 'sepal_w': 3.0, 'petal_l': 1.4, 'petal_w': 0.3},
#  {'sepal_l': 5.1, 'sepal_w': 3.8, 'petal_l': 1.6, 'petal_w': 0.2},
#  {'sepal_l': 4.6, 'sepal_w': 3.2, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 5.3, 'sepal_w': 3.7, 'petal_l': 1.5, 'petal_w': 0.2},
#  {'sepal_l': 5.0, 'sepal_w': 3.3, 'petal_l': 1.4, 'petal_w': 0.2},
#  {'sepal_l': 7.0, 'sepal_w': 3.2, 'petal_l': 4.7, 'petal_w': 1.4},
#  {'sepal_l': 6.4, 'sepal_w': 3.2, 'petal_l': 4.5, 'petal_w': 1.5},
#  {'sepal_l': 6.9, 'sepal_w': 3.1, 'petal_l': 4.9, 'petal_w': 1.5},
#  {'sepal_l': 5.5, 'sepal_w': 2.3, 'petal_l': 4.0, 'petal_w': 1.3},
#  {'sepal_l': 6.5, 'sepal_w': 2.8, 'petal_l': 4.6, 'petal_w': 1.5},
#  {'sepal_l': 5.7, 'sepal_w': 2.8, 'petal_l': 4.5, 'petal_w': 1.3},
#  {'sepal_l': 6.3, 'sepal_w': 3.3, 'petal_l': 4.7, 'petal_w': 1.6},
#  {'sepal_l': 4.9, 'sepal_w': 2.4, 'petal_l': 3.3, 'petal_w': 1.0},
#  {'sepal_l': 6.6, 'sepal_w': 2.9, 'petal_l': 4.6, 'petal_w': 1.3},
#  {'sepal_l': 5.2, 'sepal_w': 2.7, 'petal_l': 3.9, 'petal_w': 1.4},
#  {'sepal_l': 5.0, 'sepal_w': 2.0, 'petal_l': 3.5, 'petal_w': 1.0},
#  {'sepal_l': 5.9, 'sepal_w': 3.0, 'petal_l': 4.2, 'petal_w': 1.5},
#  {'sepal_l': 6.0, 'sepal_w': 2.2, 'petal_l': 4.0, 'petal_w': 1.0},
#  {'sepal_l': 6.1, 'sepal_w': 2.9, 'petal_l': 4.7, 'petal_w': 1.4},
#  {'sepal_l': 5.6, 'sepal_w': 2.9, 'petal_l': 3.6, 'petal_w': 1.3},
#  {'sepal_l': 6.7, 'sepal_w': 3.1, 'petal_l': 4.4, 'petal_w': 1.4},
#  {'sepal_l': 5.6, 'sepal_w': 3.0, 'petal_l': 4.5, 'petal_w': 1.5},
#  {'sepal_l': 5.8, 'sepal_w': 2.7, 'petal_l': 4.1, 'petal_w': 1.0},
#  {'sepal_l': 6.2, 'sepal_w': 2.2, 'petal_l': 4.5, 'petal_w': 1.5},
#  {'sepal_l': 5.6, 'sepal_w': 2.5, 'petal_l': 3.9, 'petal_w': 1.1},
#  {'sepal_l': 5.9, 'sepal_w': 3.2, 'petal_l': 4.8, 'petal_w': 1.8},
#  {'sepal_l': 6.1, 'sepal_w': 2.8, 'petal_l': 4.0, 'petal_w': 1.3},
#  {'sepal_l': 6.3, 'sepal_w': 2.5, 'petal_l': 4.9, 'petal_w': 1.5},
#  {'sepal_l': 6.1, 'sepal_w': 2.8, 'petal_l': 4.7, 'petal_w': 1.2},
#  {'sepal_l': 6.4, 'sepal_w': 2.9, 'petal_l': 4.3, 'petal_w': 1.3},
#  {'sepal_l': 6.6, 'sepal_w': 3.0, 'petal_l': 4.4, 'petal_w': 1.4},
#  {'sepal_l': 6.8, 'sepal_w': 2.8, 'petal_l': 4.8, 'petal_w': 1.4},
#  {'sepal_l': 6.7, 'sepal_w': 3.0, 'petal_l': 5.0, 'petal_w': 1.7},
#  {'sepal_l': 6.0, 'sepal_w': 2.9, 'petal_l': 4.5, 'petal_w': 1.5},
#  {'sepal_l': 5.7, 'sepal_w': 2.6, 'petal_l': 3.5, 'petal_w': 1.0},
#  {'sepal_l': 5.5, 'sepal_w': 2.4, 'petal_l': 3.8, 'petal_w': 1.1},
#  {'sepal_l': 5.5, 'sepal_w': 2.4, 'petal_l': 3.7, 'petal_w': 1.0},
#  {'sepal_l': 5.8, 'sepal_w': 2.7, 'petal_l': 3.9, 'petal_w': 1.2},
#  {'sepal_l': 6.0, 'sepal_w': 2.7, 'petal_l': 5.1, 'petal_w': 1.6},
#  {'sepal_l': 5.4, 'sepal_w': 3.0, 'petal_l': 4.5, 'petal_w': 1.5},
#  {'sepal_l': 6.0, 'sepal_w': 3.4, 'petal_l': 4.5, 'petal_w': 1.6},
#  {'sepal_l': 6.7, 'sepal_w': 3.1, 'petal_l': 4.7, 'petal_w': 1.5},
#  {'sepal_l': 6.3, 'sepal_w': 2.3, 'petal_l': 4.4, 'petal_w': 1.3},
#  {'sepal_l': 5.6, 'sepal_w': 3.0, 'petal_l': 4.1, 'petal_w': 1.3},
#  {'sepal_l': 5.5, 'sepal_w': 2.5, 'petal_l': 4.0, 'petal_w': 1.3},
#  {'sepal_l': 5.5, 'sepal_w': 2.6, 'petal_l': 4.4, 'petal_w': 1.2},
#  {'sepal_l': 6.1, 'sepal_w': 3.0, 'petal_l': 4.6, 'petal_w': 1.4},
#  {'sepal_l': 5.8, 'sepal_w': 2.6, 'petal_l': 4.0, 'petal_w': 1.2},
#  {'sepal_l': 5.0, 'sepal_w': 2.3, 'petal_l': 3.3, 'petal_w': 1.0},
#  {'sepal_l': 5.6, 'sepal_w': 2.7, 'petal_l': 4.2, 'petal_w': 1.3},
#  {'sepal_l': 5.7, 'sepal_w': 3.0, 'petal_l': 4.2, 'petal_w': 1.2},
#  {'sepal_l': 5.7, 'sepal_w': 2.9, 'petal_l': 4.2, 'petal_w': 1.3},
#  {'sepal_l': 6.2, 'sepal_w': 2.9, 'petal_l': 4.3, 'petal_w': 1.3},
#  {'sepal_l': 5.1, 'sepal_w': 2.5, 'petal_l': 3.0, 'petal_w': 1.1},
#  {'sepal_l': 5.7, 'sepal_w': 2.8, 'petal_l': 4.1, 'petal_w': 1.3},
#  {'sepal_l': 6.3, 'sepal_w': 3.3, 'petal_l': 6.0, 'petal_w': 2.5},
#  {'sepal_l': 5.8, 'sepal_w': 2.7, 'petal_l': 5.1, 'petal_w': 1.9},
#  {'sepal_l': 7.1, 'sepal_w': 3.0, 'petal_l': 5.9, 'petal_w': 2.1},
#  {'sepal_l': 6.3, 'sepal_w': 2.9, 'petal_l': 5.6, 'petal_w': 1.8},
#  {'sepal_l': 6.5, 'sepal_w': 3.0, 'petal_l': 5.8, 'petal_w': 2.2},
#  {'sepal_l': 7.6, 'sepal_w': 3.0, 'petal_l': 6.6, 'petal_w': 2.1},
#  {'sepal_l': 4.9, 'sepal_w': 2.5, 'petal_l': 4.5, 'petal_w': 1.7},
#  {'sepal_l': 7.3, 'sepal_w': 2.9, 'petal_l': 6.3, 'petal_w': 1.8},
#  {'sepal_l': 6.7, 'sepal_w': 2.5, 'petal_l': 5.8, 'petal_w': 1.8},
#  {'sepal_l': 7.2, 'sepal_w': 3.6, 'petal_l': 6.1, 'petal_w': 2.5},
#  {'sepal_l': 6.5, 'sepal_w': 3.2, 'petal_l': 5.1, 'petal_w': 2.0},
#  {'sepal_l': 6.4, 'sepal_w': 2.7, 'petal_l': 5.3, 'petal_w': 1.9},
#  {'sepal_l': 6.8, 'sepal_w': 3.0, 'petal_l': 5.5, 'petal_w': 2.1},
#  {'sepal_l': 5.7, 'sepal_w': 2.5, 'petal_l': 5.0, 'petal_w': 2.0},
#  {'sepal_l': 5.8, 'sepal_w': 2.8, 'petal_l': 5.1, 'petal_w': 2.4},
#  {'sepal_l': 6.4, 'sepal_w': 3.2, 'petal_l': 5.3, 'petal_w': 2.3},
#  {'sepal_l': 6.5, 'sepal_w': 3.0, 'petal_l': 5.5, 'petal_w': 1.8},
#  {'sepal_l': 7.7, 'sepal_w': 3.8, 'petal_l': 6.7, 'petal_w': 2.2},
#  {'sepal_l': 7.7, 'sepal_w': 2.6, 'petal_l': 6.9, 'petal_w': 2.3},
#  {'sepal_l': 6.0, 'sepal_w': 2.2, 'petal_l': 5.0, 'petal_w': 1.5},
#  {'sepal_l': 6.9, 'sepal_w': 3.2, 'petal_l': 5.7, 'petal_w': 2.3},
#  {'sepal_l': 5.6, 'sepal_w': 2.8, 'petal_l': 4.9, 'petal_w': 2.0},
#  {'sepal_l': 7.7, 'sepal_w': 2.8, 'petal_l': 6.7, 'petal_w': 2.0},
#  {'sepal_l': 6.3, 'sepal_w': 2.7, 'petal_l': 4.9, 'petal_w': 1.8},
#  {'sepal_l': 6.7, 'sepal_w': 3.3, 'petal_l': 5.7, 'petal_w': 2.1},
#  {'sepal_l': 7.2, 'sepal_w': 3.2, 'petal_l': 6.0, 'petal_w': 1.8},
#  {'sepal_l': 6.2, 'sepal_w': 2.8, 'petal_l': 4.8, 'petal_w': 1.8},
#  {'sepal_l': 6.1, 'sepal_w': 3.0, 'petal_l': 4.9, 'petal_w': 1.8},
#  {'sepal_l': 6.4, 'sepal_w': 2.8, 'petal_l': 5.6, 'petal_w': 2.1},
#  {'sepal_l': 7.2, 'sepal_w': 3.0, 'petal_l': 5.8, 'petal_w': 1.6},
#  {'sepal_l': 7.4, 'sepal_w': 2.8, 'petal_l': 6.1, 'petal_w': 1.9},
#  {'sepal_l': 7.9, 'sepal_w': 3.8, 'petal_l': 6.4, 'petal_w': 2.0},
#  {'sepal_l': 6.4, 'sepal_w': 2.8, 'petal_l': 5.6, 'petal_w': 2.2},
#  {'sepal_l': 6.3, 'sepal_w': 2.8, 'petal_l': 5.1, 'petal_w': 1.5},
#  {'sepal_l': 6.1, 'sepal_w': 2.6, 'petal_l': 5.6, 'petal_w': 1.4},
#  {'sepal_l': 7.7, 'sepal_w': 3.0, 'petal_l': 6.1, 'petal_w': 2.3},
#  {'sepal_l': 6.3, 'sepal_w': 3.4, 'petal_l': 5.6, 'petal_w': 2.4},
#  {'sepal_l': 6.4, 'sepal_w': 3.1, 'petal_l': 5.5, 'petal_w': 1.8},
#  {'sepal_l': 6.0, 'sepal_w': 3.0, 'petal_l': 4.8, 'petal_w': 1.8},
#  {'sepal_l': 6.9, 'sepal_w': 3.1, 'petal_l': 5.4, 'petal_w': 2.1},
#  {'sepal_l': 6.7, 'sepal_w': 3.1, 'petal_l': 5.6, 'petal_w': 2.4},
#  {'sepal_l': 6.9, 'sepal_w': 3.1, 'petal_l': 5.1, 'petal_w': 2.3},
#  {'sepal_l': 5.8, 'sepal_w': 2.7, 'petal_l': 5.1, 'petal_w': 1.9},
#  {'sepal_l': 6.8, 'sepal_w': 3.2, 'petal_l': 5.9, 'petal_w': 2.3},
#  {'sepal_l': 6.7, 'sepal_w': 3.3, 'petal_l': 5.7, 'petal_w': 2.5},
#  {'sepal_l': 6.7, 'sepal_w': 3.0, 'petal_l': 5.2, 'petal_w': 2.3},
#  {'sepal_l': 6.3, 'sepal_w': 2.5, 'petal_l': 5.0, 'petal_w': 1.9},
#  {'sepal_l': 6.5, 'sepal_w': 3.0, 'petal_l': 5.2, 'petal_w': 2.0},
#  {'sepal_l': 6.2, 'sepal_w': 3.4, 'petal_l': 5.4, 'petal_w': 2.3},
#  {'sepal_l': 5.9, 'sepal_w': 3.0, 'petal_l': 5.1, 'petal_w': 1.8}]

# %%
tmap = {0: 'Iris-setosa', 1: 'Iris-versicolor', 2: 'Iris-virginica'}
targets = list(map(lambda item: tmap[item], iris.target))

# %%
table = [{**row, 'species': name} for row, name in zip(table, targets)]
table
# Out:
# [{'sepal_l': 5.1,
#   'sepal_w': 3.5,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.9,
#   'sepal_w': 3.0,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.7,
#   'sepal_w': 3.2,
#   'petal_l': 1.3,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.6,
#   'sepal_w': 3.1,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.6,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.9,
#   'petal_l': 1.7,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.6,
#   'sepal_w': 3.4,
#   'petal_l': 1.4,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.4,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.4,
#   'sepal_w': 2.9,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.9,
#   'sepal_w': 3.1,
#   'petal_l': 1.5,
#   'petal_w': 0.1,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.7,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.8,
#   'sepal_w': 3.4,
#   'petal_l': 1.6,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.8,
#   'sepal_w': 3.0,
#   'petal_l': 1.4,
#   'petal_w': 0.1,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.3,
#   'sepal_w': 3.0,
#   'petal_l': 1.1,
#   'petal_w': 0.1,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.8,
#   'sepal_w': 4.0,
#   'petal_l': 1.2,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.7,
#   'sepal_w': 4.4,
#   'petal_l': 1.5,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.9,
#   'petal_l': 1.3,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.5,
#   'petal_l': 1.4,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.7,
#   'sepal_w': 3.8,
#   'petal_l': 1.7,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.8,
#   'petal_l': 1.5,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.4,
#   'petal_l': 1.7,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.7,
#   'petal_l': 1.5,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.6,
#   'sepal_w': 3.6,
#   'petal_l': 1.0,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.3,
#   'petal_l': 1.7,
#   'petal_w': 0.5,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.8,
#   'sepal_w': 3.4,
#   'petal_l': 1.9,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.0,
#   'petal_l': 1.6,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.4,
#   'petal_l': 1.6,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.2,
#   'sepal_w': 3.5,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.2,
#   'sepal_w': 3.4,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.7,
#   'sepal_w': 3.2,
#   'petal_l': 1.6,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.8,
#   'sepal_w': 3.1,
#   'petal_l': 1.6,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.4,
#   'petal_l': 1.5,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.2,
#   'sepal_w': 4.1,
#   'petal_l': 1.5,
#   'petal_w': 0.1,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.5,
#   'sepal_w': 4.2,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.9,
#   'sepal_w': 3.1,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.2,
#   'petal_l': 1.2,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.5,
#   'sepal_w': 3.5,
#   'petal_l': 1.3,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.9,
#   'sepal_w': 3.6,
#   'petal_l': 1.4,
#   'petal_w': 0.1,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.4,
#   'sepal_w': 3.0,
#   'petal_l': 1.3,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.4,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.5,
#   'petal_l': 1.3,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.5,
#   'sepal_w': 2.3,
#   'petal_l': 1.3,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.4,
#   'sepal_w': 3.2,
#   'petal_l': 1.3,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.5,
#   'petal_l': 1.6,
#   'petal_w': 0.6,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.8,
#   'petal_l': 1.9,
#   'petal_w': 0.4,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.8,
#   'sepal_w': 3.0,
#   'petal_l': 1.4,
#   'petal_w': 0.3,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.1,
#   'sepal_w': 3.8,
#   'petal_l': 1.6,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 4.6,
#   'sepal_w': 3.2,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.3,
#   'sepal_w': 3.7,
#   'petal_l': 1.5,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 5.0,
#   'sepal_w': 3.3,
#   'petal_l': 1.4,
#   'petal_w': 0.2,
#   'species': 'Iris-setosa'},
#  {'sepal_l': 7.0,
#   'sepal_w': 3.2,
#   'petal_l': 4.7,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.4,
#   'sepal_w': 3.2,
#   'petal_l': 4.5,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.9,
#   'sepal_w': 3.1,
#   'petal_l': 4.9,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.5,
#   'sepal_w': 2.3,
#   'petal_l': 4.0,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.5,
#   'sepal_w': 2.8,
#   'petal_l': 4.6,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.7,
#   'sepal_w': 2.8,
#   'petal_l': 4.5,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.3,
#   'sepal_w': 3.3,
#   'petal_l': 4.7,
#   'petal_w': 1.6,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 4.9,
#   'sepal_w': 2.4,
#   'petal_l': 3.3,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.6,
#   'sepal_w': 2.9,
#   'petal_l': 4.6,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.2,
#   'sepal_w': 2.7,
#   'petal_l': 3.9,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.0,
#   'sepal_w': 2.0,
#   'petal_l': 3.5,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.9,
#   'sepal_w': 3.0,
#   'petal_l': 4.2,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.0,
#   'sepal_w': 2.2,
#   'petal_l': 4.0,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.1,
#   'sepal_w': 2.9,
#   'petal_l': 4.7,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.6,
#   'sepal_w': 2.9,
#   'petal_l': 3.6,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.1,
#   'petal_l': 4.4,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.6,
#   'sepal_w': 3.0,
#   'petal_l': 4.5,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.7,
#   'petal_l': 4.1,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.2,
#   'sepal_w': 2.2,
#   'petal_l': 4.5,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.6,
#   'sepal_w': 2.5,
#   'petal_l': 3.9,
#   'petal_w': 1.1,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.9,
#   'sepal_w': 3.2,
#   'petal_l': 4.8,
#   'petal_w': 1.8,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.1,
#   'sepal_w': 2.8,
#   'petal_l': 4.0,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.5,
#   'petal_l': 4.9,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.1,
#   'sepal_w': 2.8,
#   'petal_l': 4.7,
#   'petal_w': 1.2,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.4,
#   'sepal_w': 2.9,
#   'petal_l': 4.3,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.6,
#   'sepal_w': 3.0,
#   'petal_l': 4.4,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.8,
#   'sepal_w': 2.8,
#   'petal_l': 4.8,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.0,
#   'petal_l': 5.0,
#   'petal_w': 1.7,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.0,
#   'sepal_w': 2.9,
#   'petal_l': 4.5,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.7,
#   'sepal_w': 2.6,
#   'petal_l': 3.5,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.5,
#   'sepal_w': 2.4,
#   'petal_l': 3.8,
#   'petal_w': 1.1,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.5,
#   'sepal_w': 2.4,
#   'petal_l': 3.7,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.7,
#   'petal_l': 3.9,
#   'petal_w': 1.2,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.0,
#   'sepal_w': 2.7,
#   'petal_l': 5.1,
#   'petal_w': 1.6,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.4,
#   'sepal_w': 3.0,
#   'petal_l': 4.5,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.0,
#   'sepal_w': 3.4,
#   'petal_l': 4.5,
#   'petal_w': 1.6,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.1,
#   'petal_l': 4.7,
#   'petal_w': 1.5,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.3,
#   'petal_l': 4.4,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.6,
#   'sepal_w': 3.0,
#   'petal_l': 4.1,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.5,
#   'sepal_w': 2.5,
#   'petal_l': 4.0,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.5,
#   'sepal_w': 2.6,
#   'petal_l': 4.4,
#   'petal_w': 1.2,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.1,
#   'sepal_w': 3.0,
#   'petal_l': 4.6,
#   'petal_w': 1.4,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.6,
#   'petal_l': 4.0,
#   'petal_w': 1.2,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.0,
#   'sepal_w': 2.3,
#   'petal_l': 3.3,
#   'petal_w': 1.0,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.6,
#   'sepal_w': 2.7,
#   'petal_l': 4.2,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.7,
#   'sepal_w': 3.0,
#   'petal_l': 4.2,
#   'petal_w': 1.2,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.7,
#   'sepal_w': 2.9,
#   'petal_l': 4.2,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.2,
#   'sepal_w': 2.9,
#   'petal_l': 4.3,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.1,
#   'sepal_w': 2.5,
#   'petal_l': 3.0,
#   'petal_w': 1.1,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 5.7,
#   'sepal_w': 2.8,
#   'petal_l': 4.1,
#   'petal_w': 1.3,
#   'species': 'Iris-versicolor'},
#  {'sepal_l': 6.3,
#   'sepal_w': 3.3,
#   'petal_l': 6.0,
#   'petal_w': 2.5,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.7,
#   'petal_l': 5.1,
#   'petal_w': 1.9,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.1,
#   'sepal_w': 3.0,
#   'petal_l': 5.9,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.9,
#   'petal_l': 5.6,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.5,
#   'sepal_w': 3.0,
#   'petal_l': 5.8,
#   'petal_w': 2.2,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.6,
#   'sepal_w': 3.0,
#   'petal_l': 6.6,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 4.9,
#   'sepal_w': 2.5,
#   'petal_l': 4.5,
#   'petal_w': 1.7,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.3,
#   'sepal_w': 2.9,
#   'petal_l': 6.3,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.7,
#   'sepal_w': 2.5,
#   'petal_l': 5.8,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.2,
#   'sepal_w': 3.6,
#   'petal_l': 6.1,
#   'petal_w': 2.5,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.5,
#   'sepal_w': 3.2,
#   'petal_l': 5.1,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.4,
#   'sepal_w': 2.7,
#   'petal_l': 5.3,
#   'petal_w': 1.9,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.8,
#   'sepal_w': 3.0,
#   'petal_l': 5.5,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.7,
#   'sepal_w': 2.5,
#   'petal_l': 5.0,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.8,
#   'petal_l': 5.1,
#   'petal_w': 2.4,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.4,
#   'sepal_w': 3.2,
#   'petal_l': 5.3,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.5,
#   'sepal_w': 3.0,
#   'petal_l': 5.5,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.7,
#   'sepal_w': 3.8,
#   'petal_l': 6.7,
#   'petal_w': 2.2,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.7,
#   'sepal_w': 2.6,
#   'petal_l': 6.9,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.0,
#   'sepal_w': 2.2,
#   'petal_l': 5.0,
#   'petal_w': 1.5,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.9,
#   'sepal_w': 3.2,
#   'petal_l': 5.7,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.6,
#   'sepal_w': 2.8,
#   'petal_l': 4.9,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.7,
#   'sepal_w': 2.8,
#   'petal_l': 6.7,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.7,
#   'petal_l': 4.9,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.3,
#   'petal_l': 5.7,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.2,
#   'sepal_w': 3.2,
#   'petal_l': 6.0,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.2,
#   'sepal_w': 2.8,
#   'petal_l': 4.8,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.1,
#   'sepal_w': 3.0,
#   'petal_l': 4.9,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.4,
#   'sepal_w': 2.8,
#   'petal_l': 5.6,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.2,
#   'sepal_w': 3.0,
#   'petal_l': 5.8,
#   'petal_w': 1.6,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.4,
#   'sepal_w': 2.8,
#   'petal_l': 6.1,
#   'petal_w': 1.9,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.9,
#   'sepal_w': 3.8,
#   'petal_l': 6.4,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.4,
#   'sepal_w': 2.8,
#   'petal_l': 5.6,
#   'petal_w': 2.2,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.8,
#   'petal_l': 5.1,
#   'petal_w': 1.5,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.1,
#   'sepal_w': 2.6,
#   'petal_l': 5.6,
#   'petal_w': 1.4,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 7.7,
#   'sepal_w': 3.0,
#   'petal_l': 6.1,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.3,
#   'sepal_w': 3.4,
#   'petal_l': 5.6,
#   'petal_w': 2.4,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.4,
#   'sepal_w': 3.1,
#   'petal_l': 5.5,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.0,
#   'sepal_w': 3.0,
#   'petal_l': 4.8,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.9,
#   'sepal_w': 3.1,
#   'petal_l': 5.4,
#   'petal_w': 2.1,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.1,
#   'petal_l': 5.6,
#   'petal_w': 2.4,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.9,
#   'sepal_w': 3.1,
#   'petal_l': 5.1,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.8,
#   'sepal_w': 2.7,
#   'petal_l': 5.1,
#   'petal_w': 1.9,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.8,
#   'sepal_w': 3.2,
#   'petal_l': 5.9,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.3,
#   'petal_l': 5.7,
#   'petal_w': 2.5,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.7,
#   'sepal_w': 3.0,
#   'petal_l': 5.2,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.3,
#   'sepal_w': 2.5,
#   'petal_l': 5.0,
#   'petal_w': 1.9,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.5,
#   'sepal_w': 3.0,
#   'petal_l': 5.2,
#   'petal_w': 2.0,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 6.2,
#   'sepal_w': 3.4,
#   'petal_l': 5.4,
#   'petal_w': 2.3,
#   'species': 'Iris-virginica'},
#  {'sepal_l': 5.9,
#   'sepal_w': 3.0,
#   'petal_l': 5.1,
#   'petal_w': 1.8,
#   'species': 'Iris-virginica'}]

# %%
import pandas as pd
df = pd.DataFrame(table)
df
# Out:
#      sepal_l  sepal_w  petal_l  petal_w         species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import copy


class EarlyStopping:
    def __init__(self, patience=5, min_delta=0, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta
        self.restore_best_weights = restore_best_weights
        self.best_model = None
        self.best_loss = None
        self.counter = 0
        self.status = ""

    def __call__(self, model, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.best_model = copy.deepcopy(model.state_dict())
        elif self.best_loss - val_loss >= self.min_delta:
            self.best_model = copy.deepcopy(model.state_dict())
            self.best_loss = val_loss
            self.counter = 0
            self.status = f"Improvement found, counter reset to {self.counter}"
        else:
            self.counter += 1
            self.status = f"No improvement in the last {self.counter} epochs"
            if self.counter >= self.patience:
                self.status = f"Early stopping triggered after {self.counter} epochs."
                if self.restore_best_weights:
                    model.load_state_dict(self.best_model)
                return True
        return False

# %%
import time

import numpy as np
import pandas as pd
import torch
import tqdm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# Set random seed for reproducibility
np.random.seed(42)
torch.manual_seed(42)

def load_data():
    src = df.copy()

    le = LabelEncoder()

    x = src[["sepal_l", "sepal_w", "petal_l", "petal_w"]].values
    y = le.fit_transform(df["species"])
    species = le.classes_

    # Split into validation and training sets
    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.25, random_state=42
    )

    scaler = StandardScaler()
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)

    # Numpy to Torch Tensor
    x_train = torch.tensor(x_train, device=device, dtype=torch.float32)
    y_train = torch.tensor(y_train, device=device, dtype=torch.long)

    x_test = torch.tensor(x_test, device=device, dtype=torch.float32)
    y_test = torch.tensor(y_test, device=device, dtype=torch.long)

    return x_train, x_test, y_train, y_test, species


x_train, x_test, y_train, y_test, species = load_data()

# %%
import time

import numpy as np
import pandas as pd
import torch
import tqdm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# Create datasets
BATCH_SIZE = 16

dataset_train = TensorDataset(x_train, y_train)
dataloader_train = DataLoader(
    dataset_train, batch_size=BATCH_SIZE, shuffle=True)

dataset_test = TensorDataset(x_test, y_test)
dataloader_test = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True)

# Create model using nn.Sequential
model = nn.Sequential(
    nn.Linear(x_train.shape[1], 50),
    nn.ReLU(),
    nn.Linear(50, 25),
    nn.ReLU(),
    nn.Linear(25, len(species)),
    nn.LogSoftmax(dim=1),
)

model = torch.compile(model,backend="aot_eager").to(device)

loss_fn = nn.CrossEntropyLoss()  # cross entropy loss

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
es = EarlyStopping()

epoch = 0
done = False
while epoch < 1000 and not done:
    epoch += 1
    steps = list(enumerate(dataloader_train))
    pbar = tqdm.tqdm(steps)
    model.train()
    for i, (x_batch, y_batch) in pbar:
        y_batch_pred = model(x_batch.to(device))
        loss = loss_fn(y_batch_pred, y_batch.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss, current = loss.item(), (i + 1) * len(x_batch)
        if i == len(steps) - 1:
            model.eval()
            pred = model(x_test)
            vloss = loss_fn(pred, y_test)
            if es(model, vloss):
                done = True
            pbar.set_description(
                f"Epoch: {epoch}, tloss: {loss}, vloss: {vloss:>7f}, {es.status}"
            )
        else:
            pbar.set_description(f"Epoch: {epoch}, tloss {loss:}")
# Out:
# Epoch: 1, tloss: 0.6026307344436646, vloss: 0.536555, : 100%|██████████| 7/7 [00:00<00:00,  7.70it/s]
# Epoch: 2, tloss: 0.3658648133277893, vloss: 0.277725, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 401.73it/s]
# Epoch: 3, tloss: 0.15603026747703552, vloss: 0.187535, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 414.63it/s]
# Epoch: 4, tloss: 0.057948920875787735, vloss: 0.154333, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 388.62it/s]
# Epoch: 5, tloss: 0.18528974056243896, vloss: 0.076723, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 396.41it/s]
# Epoch: 6, tloss: 0.12420050799846649, vloss: 0.061499, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 384.29it/s]
# Epoch: 7, tloss: 0.03340417519211769, vloss: 0.045322, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 426.23it/s]
# Epoch: 8, tloss: 0.09452513605356216, vloss: 0.032975, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 416.72it/s]
# Epoch: 9, tloss: 0.005208526272326708, vloss: 0.023963, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 384.62it/s]
# Epoch: 10, tloss: 0.06230875477194786, vloss: 0.015515, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 431.55it/s]
# Epoch: 11, tloss: 0.08908900618553162, vloss: 0.038119, No improvement in the last 1 epochs: 100%|██████████| 7/7 [00:00<00:00, 408.87it/s]
# Epoch: 12, tloss: 0.034965552389621735, vloss: 0.026789, No improvement in the last 2 epochs: 100%|██████████| 7/7 [00:00<00:00, 385.04it/s]
# Epoch: 13, tloss: 0.06976646929979324, vloss: 0.018425, No improvement in the last 3 epochs: 100%|██████████| 7/7 [00:00<00:00, 413.60it/s]
# Epoch: 14, tloss: 0.013938353396952152, vloss: 0.010584, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 408.98it/s]
# Epoch: 15, tloss: 0.03223251551389694, vloss: 0.008987, Improvement found, counter reset to 0: 100%|██████████| 7/7 [00:00<00:00, 397.57it/s]
# Epoch: 16, tloss: 0.009036803618073463, vloss: 0.016889, No improvement in the last 1 epochs: 100%|██████████| 7/7 [00:00<00:00, 383.89it/s]
# Epoch: 17, tloss: 0.009504583664238453, vloss: 0.014087, No improvement in the last 2 epochs: 100%|██████████| 7/7 [00:00<00:00, 416.10it/s]
# Epoch: 18, tloss: 0.0577940009534359, vloss: 0.012317, No improvement in the last 3 epochs: 100%|██████████| 7/7 [00:00<00:00, 433.97it/s]
# Epoch: 19, tloss: 0.001863109297119081, vloss: 0.012097, No improvement in the last 4 epochs: 100%|██████████| 7/7 [00:00<00:00, 416.16it/s]
# Epoch: 20, tloss: 0.01049288734793663, vloss: 0.011086, Early stopping triggered after 5 epochs.: 100%|██████████| 7/7 [00:00<00:00, 382.82it/s]
