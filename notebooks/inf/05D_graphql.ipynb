# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbolek/learning/blob/with_stack/notebooks/inf/05D_graphql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GraphQL

# %% [markdown]
# > **Doprovodný komentář**
# >
# > https://www.youtube.com/watch?v=VztkWM5nO58

# %% [markdown]
# https://www.howtographql.com/
#
# GraphQL je jazyk (standard), který umožňuje vytvářet složité strukturované dotazy. Součastí jsou knihovny pro různé jazyky (javascript, Python, C#), s jejichž pomocí lze GraphQL servery vytvářet, případně se takových serverů dotazovat.

# %% [markdown]
# ## Libraries

# %% [markdown]
# Pro jazyk Python byla vybrána jako ukázková knihovna graphene. Aplikaci založenou na graphene spustíme pomocí FastAPI, které již znáte.

# %%
# !pip install graphene
# Out:
# Requirement already satisfied: graphene in /opt/conda/lib/python3.9/site-packages (3.0)
# Requirement already satisfied: graphql-relay<4,>=3.0 in /opt/conda/lib/python3.9/site-packages (from graphene) (3.1.5)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/conda/lib/python3.9/site-packages (from graphene) (9.0.1)
# Requirement already satisfied: graphql-core~=3.1.2 in /opt/conda/lib/python3.9/site-packages (from graphene) (3.1.7)

# %%
# !pip install starlette_graphene3
# Out:
# Requirement already satisfied: starlette_graphene3 in /opt/conda/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: starlette>=0.14.1 in /opt/conda/lib/python3.9/site-packages (from starlette_graphene3) (0.19.1)
# Requirement already satisfied: graphene>=3.0b6 in /opt/conda/lib/python3.9/site-packages (from starlette_graphene3) (3.0)
# Requirement already satisfied: graphql-core~=3.1.2 in /opt/conda/lib/python3.9/site-packages (from graphene>=3.0b6->starlette_graphene3) (3.1.7)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/conda/lib/python3.9/site-packages (from graphene>=3.0b6->starlette_graphene3) (9.0.1)
# Requirement already satisfied: graphql-relay<4,>=3.0 in /opt/conda/lib/python3.9/site-packages (from graphene>=3.0b6->starlette_graphene3) (3.1.5)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.9/site-packages (from starlette>=0.14.1->starlette_graphene3) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from starlette>=0.14.1->starlette_graphene3) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette>=0.14.1->starlette_graphene3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette>=0.14.1->starlette_graphene3) (3.3)

# %% [markdown]
# ## Helper Func for App in Notebook

# %% [markdown]
# V ukázkách dále bude použit kód, který je specifický pro prostředí jupyter a který tak umožňuje spouštět ukázky přímo v notebooku. Fakticky je kódem vytvořen subproces, který zabezpečuje běh serveru. Identifikace subprocesu je uložena v datové struktuře `servers`. Díky tomu lze identifikovat, zda na požadovaném portu již nějaký server běží a v případě potřeby jej zastavit a spustit nový server.
#
# Po ukončení experimentů se serverem (kódem) je nutné tento server zastavit, aby došlo k uvolnění portu. V případě problémů je možné, že bude nezbytné restartovat jupyter, aby byly porty uvolněny. Je-li spuštěn nový server, aniž by běžící na stejném portu byl ukončen, dojde k chybovému stavu.
#
# ```python
# assert port in [9991, 9992, 9993, 9994]
# ```
# Slouží k ověření, že požadovaný port je dostupný i z prostředí mimo jupyter. Vzpomeňte si na konfiguraci docker stacku a mapování portů mimo jupyter kontejner.

# %%
# !pip install uvicorn[standard]
# !pip install fastapi
# Out:
# Requirement already satisfied: uvicorn[standard] in /opt/conda/lib/python3.9/site-packages (0.17.6)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (8.1.3)
# Requirement already satisfied: asgiref>=3.4.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (3.5.2)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (0.13.0)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (10.3)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (0.16.0)
# Requirement already satisfied: httptools>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (0.4.0)
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (6.0)
# Requirement already satisfied: watchgod>=0.6 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (0.8.2)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]) (0.20.0)
# Requirement already satisfied: anyio<4,>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from watchgod>=0.6->uvicorn[standard]) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.0.0->watchgod>=0.6->uvicorn[standard]) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.0.0->watchgod>=0.6->uvicorn[standard]) (3.3)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.9/site-packages (0.78.0)
# Requirement already satisfied: starlette==0.19.1 in /opt/conda/lib/python3.9/site-packages (from fastapi) (0.19.1)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /opt/conda/lib/python3.9/site-packages (from fastapi) (1.9.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from starlette==0.19.1->fastapi) (4.2.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.9/site-packages (from starlette==0.19.1->fastapi) (3.5.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi) (1.2.0)

# %%
# Code in this cell is just for (re)starting the API on a Process, and other compatibility stuff with Jupyter cells.
# Just ignore it!
import uvicorn
from multiprocessing import Process

servers = {}
_api_process = None

def start_api(app=None, port=9992, runNew=True):
    """Stop the API if running; Start the API; Wait until API (port) is available (reachable)"""
    assert port in [9991, 9992, 9993, 9994], f'port has unexpected value {port}'
    def run():
        uvicorn.run(app, port=port, host='0.0.0.0', root_path='')    
        
    _api_process = servers.get(port, None)
    if _api_process:
        _api_process.terminate()
        _api_process.join()
        del servers[port]
    
    if runNew:
        assert (not app is None), 'app is None'
        _api_process = Process(target=run, daemon=True)
        _api_process.start()
        servers[port] = _api_process

# %% [markdown]
# ## First GQL App

# %% [markdown]
# ### GQL Models

# %% [markdown]
# Důležitým prvkem definice jsou datové struktury, které GraphQL zprostředkovává. V nejjednodušší variantě tyto odpovídají strukturám tabulek (pro případ relačních databází).
#
# Datové struktury deklarujeme jako třídy odvozené od `graphene.ObjectType`. Součástí deklarace jsou položky, které lze získat přímo z tabulky a také položky, které je možné získat jen s využitím relací.
#
# Velmi často pro položky, které jsou součástí tabulek, lze využít implicitní resolver. To znamená, že Graphene si může odvodit, odkud lze získat odpovídající data. Je také ale možné použít explicitní resolver (viz definice třídy `UserGQL` a metody `resolve_groups`). U explicitního resolveru parametr `parent` obsahuje datovou strukturu, ze které má být příslušná položka získána. Modely definované níže mají explicitní resolvery, které vracejí "prázdné" hodnoty. Plná implementace je uvedena v další kapitole.

# %%
import graphene

class UserGQL(graphene.ObjectType):
    """Represents an user. User can be connected to several groups where the user is member. Also the user can play several roles."""
    id = graphene.ID()
    name = graphene.String()
    surname = graphene.String()
    email = graphene.String()
    
    groups = graphene.Field(graphene.List(lambda: GroupGQL))
    
    def resolve_groups(parent, info):
        return []
        
class GroupTypeGQL(graphene.ObjectType): 
    """"Represents a type of group such as "faculty" or "department". """
    id = graphene.ID()
    name = graphene.String()
    
    groups = graphene.List(lambda: GroupGQL)   
    
    def resolve_groups(parent, info):
        groupTypeId = parent.id
        result = []
        return result
    
class GroupGQL(graphene.ObjectType):
    """"Represents a group which has several members - users. Group is defined by its type, also it has a parent and children."""
    id = graphene.ID()
    name = graphene.String()
    users = graphene.List(UserGQL)
    
    def resolve_users(parent, info):
        groupId = parent.id
        result = []
        return result

    grouptype = graphene.Field(lambda: GroupTypeGQL)
    
    def resolve_grouptype(parent, info):
        return None

# %% [markdown]
# ### Query Root

# %% [markdown]
# Níže definovaná třída `QueryGQL` je "vrcholem", přes který lze získávat "hlavní" datové struktury. Je tak první strukturou, s jejíž pomocí je případný dotaz obsluhován. Níže uvedená implementace fakticky vrací konstanty.

# %%
import graphene

class QueryGQL(graphene.ObjectType):
    user = graphene.Field(UserGQL, id = graphene.ID(required = True))
    group = graphene.Field(GroupGQL, id = graphene.ID(required = True))
    grouptype = graphene.Field(GroupTypeGQL, id = graphene.ID(required = True))
    
    def resolve_user(root, info, id):
        return {'id': id, 'name': 'John', 'surname': 'Newbie'}
    
    def resolve_group(root, info, id):
        return {'id': id, 'name': 'FVT'}
    
    def resolve_grouptype(root, info, id):
        return {'id': id, 'name': 'faculty'}

# %% [markdown]
# ### App

# %% [markdown]
# Finální kousek kódu, který naváže aplikaci na URI adresu. Po spuštění následující buňky poběží server, na který se můžete podívat prostřednictvím adresy
# http://localhost:31102/gql

# %%
import requests

def singleCache(f):
    cache = None
    def decorated():
        nonlocal cache
        if cache is None:
            fResult = f()
            cache = fResult.replace('https://swapi-graphql.netlify.app/.netlify/functions/index', '/gql')
        else:
            #print('cached')
            pass
        return cache
    return decorated

@singleCache
def getSwapi():
    source = "https://raw.githubusercontent.com/graphql/swapi-graphql/master/public/index.html"
    import requests
    r = requests.get(source)
    return r.text

# %%
#from starlette.graphql import GraphQLApp
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI
import fastapi

graphql_app = GraphQLApp(schema=graphene.Schema(query=QueryGQL), on_get=make_graphiql_handler())

app = FastAPI()#root_path='/api')

@app.get('/')
def hello():
    return {'hello': 'world'}


@app.get('/gql/', response_class=fastapi.responses.HTMLResponse)
def swapiUI():
    return getSwapi()

app.add_route('/gql/', graphql_app, methods=['POST'])

start_api(app=app, port=9992, runNew=True)
# Out:
# INFO:     Started server process [31611]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     172.18.0.1:43454 - "GET /gql?query=%23%20Welcome%20to%20GraphiQL%0A%23%0A%23%20GraphiQL%20is%20an%20in-browser%20tool%20for%20writing%2C%20validating%2C%20and%0A%23%20testing%20GraphQL%20queries.%0A%23%0A%23%20Type%20queries%20into%20this%20side%20of%20the%20screen%2C%20and%20you%20will%20see%20intelligent%0A%23%20typeaheads%20aware%20of%20the%20current%20GraphQL%20type%20schema%20and%20live%20syntax%20and%0A%23%20validation%20errors%20highlighted%20within%20the%20text.%0A%23%0A%23%20GraphQL%20queries%20typically%20start%20with%20a%20%22%7B%22%20character.%20Lines%20that%20starts%0A%23%20with%20a%20%23%20are%20ignored.%0A%23%0A%23%20An%20example%20GraphQL%20query%20might%20look%20like%3A%0A%23%0A%23%20%20%20%20%20%7B%0A%23%20%20%20%20%20%20%20field(arg%3A%20%22value%22)%20%7B%0A%23%20%20%20%20%20%20%20%20%20subField%0A%23%20%20%20%20%20%20%20%7D%0A%23%20%20%20%20%20%7D%0A%23%0A%23%20Keyboard%20shortcuts%3A%0A%23%0A%23%20%20Prettify%20Query%3A%20%20Shift-Ctrl-P%20(or%20press%20the%20prettify%20button%20above)%0A%23%0A%23%20%20%20%20%20%20%20Run%20Query%3A%20%20Ctrl-Enter%20(or%20press%20the%20play%20button%20above)%0A%23%0A%23%20%20%20Auto%20Complete%3A%20%20Ctrl-Space%20(or%20just%20start%20typing)%0A%23%0A%0Amutation%20%7B%0A%20%20ua%3A%20createUser(user%3A%20%7Bname%3A%20%22John%22%2C%20surname%3A%20%22Newmann%22%7D)%20%7B%0A%20%20%20%20ok%0A%20%20%20%20result%20%7B%0A%20%20%20%20%20%20id%0A%20%20%20%20%20%20name%0A%20%20%20%20%20%20surname%0A%20%20%20%20%7D%0A%20%20%7D%0A%20%20ub%3A%20createUser(user%3A%20%7Bname%3A%20%22Jane%22%2C%20surname%3A%20%22Sun%22%7D)%20%7B%0A%20%20%20%20ok%0A%20%20%20%20result%20%7B%0A%20%20%20%20%20%20id%0A%20%20%20%20%20%20name%0A%20%20%20%20%20%20surname%0A%20%20%20%20%7D%0A%20%20%7D%0A%7D HTTP/1.1" 307 Temporary Redirect
# INFO:     172.18.0.1:43454 - "GET /gql/?query=%23%20Welcome%20to%20GraphiQL%0A%23%0A%23%20GraphiQL%20is%20an%20in-browser%20tool%20for%20writing%2C%20validating%2C%20and%0A%23%20testing%20GraphQL%20queries.%0A%23%0A%23%20Type%20queries%20into%20this%20side%20of%20the%20screen%2C%20and%20you%20will%20see%20intelligent%0A%23%20typeaheads%20aware%20of%20the%20current%20GraphQL%20type%20schema%20and%20live%20syntax%20and%0A%23%20validation%20errors%20highlighted%20within%20the%20text.%0A%23%0A%23%20GraphQL%20queries%20typically%20start%20with%20a%20%22%7B%22%20character.%20Lines%20that%20starts%0A%23%20with%20a%20%23%20are%20ignored.%0A%23%0A%23%20An%20example%20GraphQL%20query%20might%20look%20like%3A%0A%23%0A%23%20%20%20%20%20%7B%0A%23%20%20%20%20%20%20%20field(arg%3A%20%22value%22)%20%7B%0A%23%20%20%20%20%20%20%20%20%20subField%0A%23%20%20%20%20%20%20%20%7D%0A%23%20%20%20%20%20%7D%0A%23%0A%23%20Keyboard%20shortcuts%3A%0A%23%0A%23%20%20Prettify%20Query%3A%20%20Shift-Ctrl-P%20(or%20press%20the%20prettify%20button%20above)%0A%23%0A%23%20%20%20%20%20%20%20Run%20Query%3A%20%20Ctrl-Enter%20(or%20press%20the%20play%20button%20above)%0A%23%0A%23%20%20%20Auto%20Complete%3A%20%20Ctrl-Space%20(or%20just%20start%20typing)%0A%23%0A%0Amutation%20%7B%0A%20%20ua%3A%20createUser(user%3A%20%7Bname%3A%20%22John%22%2C%20surname%3A%20%22Newmann%22%7D)%20%7B%0A%20%20%20%20ok%0A%20%20%20%20result%20%7B%0A%20%20%20%20%20%20id%0A%20%20%20%20%20%20name%0A%20%20%20%20%20%20surname%0A%20%20%20%20%7D%0A%20%20%7D%0A%20%20ub%3A%20createUser(user%3A%20%7Bname%3A%20%22Jane%22%2C%20surname%3A%20%22Sun%22%7D)%20%7B%0A%20%20%20%20ok%0A%20%20%20%20result%20%7B%0A%20%20%20%20%20%20id%0A%20%20%20%20%20%20name%0A%20%20%20%20%20%20surname%0A%20%20%20%20%7D%0A%20%20%7D%0A%7D HTTP/1.1" 200 OK
# INFO:     172.18.0.1:43454 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     172.18.0.1:43454 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:43454 - "GET /gql/favicon.ico HTTP/1.1" 404 Not Found
# INFO:     ('172.18.0.1', 43520) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.18.0.1:44088 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     172.18.0.1:44088 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.18.0.1', 45136) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46764) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48386) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50024) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51646) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53284) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54902) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56512) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58120) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59726) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33098) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34716) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36320) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37922) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39546) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41148) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42768) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44390) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46000) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47634) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49236) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50852) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52468) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54090) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55688) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57300) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58940) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60560) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33952) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35584) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37206) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38830) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40432) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42048) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43674) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45294) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46932) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48548) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50176) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51788) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53402) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55000) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56622) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58240) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59846) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33234) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34852) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36470) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38068) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39672) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41304) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42920) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44532) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46148) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47756) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49360) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50974) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52586) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54210) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55820) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57454) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59088) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60710) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34094) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35722) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37340) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38934) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40558) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42180) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43814) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45428) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47040) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48652) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50260) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51878) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53502) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55116) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56738) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58360) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59966) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33346) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34958) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36582) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38194) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39812) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41428) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43040) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44650) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46246) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47866) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49486) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51092) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52704) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54326) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55938) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57570) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59170) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60794) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34182) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35810) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37410) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39032) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40636) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42238) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43868) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45476) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47106) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48736) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50354) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51984) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53604) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55226) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56840) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58456) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60062) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33462) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35090) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36700) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38324) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39928) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41544) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43238) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44866) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46478) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48178) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49784) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51392) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53002) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54604) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56224) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57850) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59468) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 32838) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34474) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36106) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37728) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39336) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40964) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42584) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44200) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45824) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47430) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49030) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50652) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52254) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53858) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55538) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57148) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58762) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60400) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33780) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35386) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36988) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38612) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40238) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41852) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43458) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45074) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46682) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48296) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49892) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51504) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53126) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54732) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56328) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57940) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59560) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 32960) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34582) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36206) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37826) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39438) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41054) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42670) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44270) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45882) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47508) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49152) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50774) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52398) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54014) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55644) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57240) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58850) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60476) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33862) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35482) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37128) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38722) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40336) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41972) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43594) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45216) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46828) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48454) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50072) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51702) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53330) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54944) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56562) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58172) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59796) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33192) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34806) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36414) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38014) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39646) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41266) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42886) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44488) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46114) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47740) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49360) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50970) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52580) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54176) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55786) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57404) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59024) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60626) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34016) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35634) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37242) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38866) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40492) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42096) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43718) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45334) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46958) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48596) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50198) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51802) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53434) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55034) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56644) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58256) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59872) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33342) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34966) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36592) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38206) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39810) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41420) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43036) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44670) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46282) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47912) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49518) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51118) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52728) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54360) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55966) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57588) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59204) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60830) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34210) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35814) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37424) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39046) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40668) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42274) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43890) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45514) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47110) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48738) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50352) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51980) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53604) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55224) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56840) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58464) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60088) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33482) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35106) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36728) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38320) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39936) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41552) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43178) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44800) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46412) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48024) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49626) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51252) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52878) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54506) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56120) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57736) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59342) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60978) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34378) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36000) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37628) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39236) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40868) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42496) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44122) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45746) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47352) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48970) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50590) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52188) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53812) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55430) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57054) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58676) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60290) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33656) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35268) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36894) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38504) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40122) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41732) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43334) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44954) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46570) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48192) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49810) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51436) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53036) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54654) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56264) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57894) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59514) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 32904) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34540) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36152) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37758) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39370) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40978) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42578) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44208) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45832) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47458) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49066) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50704) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52306) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53930) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55574) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57194) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58820) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60420) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# ...
# INFO:     ('172.18.0.1', 49126) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50750) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52372) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53968) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55578) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57182) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58790) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60386) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33774) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35384) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37000) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38616) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40230) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41840) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43466) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45096) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46720) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48336) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49952) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51558) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53190) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54810) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56428) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58046) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59682) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33062) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34660) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35684) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37302) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38932) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40560) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42178) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43786) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45406) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47018) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48634) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50250) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51868) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53490) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55110) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56722) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58348) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59970) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33356) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34974) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36574) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38204) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39820) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41424) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43040) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44660) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46260) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47968) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49598) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51230) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52848) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54472) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56090) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57712) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58450) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59096) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59168) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59222) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59296) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59378) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59688) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59774) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60056) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60338) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60594) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60958) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33266) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34092) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35324) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36926) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38720) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40330) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41958) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43570) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45182) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46798) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48416) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50040) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51642) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53254) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54860) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56462) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58072) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59694) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33076) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 34708) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 36322) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37960) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 39578) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 41190) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42802) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 44434) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46042) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 47652) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 49252) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50858) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 52476) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54094) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 55706) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 57330) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58936) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 60546) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33936) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 35544) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 37174) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 38782) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 40400) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 42006) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 43626) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 45250) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 46860) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 48464) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 50076) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 51696) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 53302) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 54912) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 56542) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 58164) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 59776) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.18.0.1', 33152) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed

# %% [markdown]
# Prohlédněte si http://localhost:31102/gql
#
# Vyzkoušejte si dotazy
#
# > Dotaz 1
#
# ```json
# query {
#   user(id: 1) {
#     id
#     name
#     surname
#   }
# }
# ```
#
# > Dotaz 2
#
# ```json
# query {
#   group(id: 1) {
#     id
#     name
#   }
# }
# ```
#
# > Dotaz 3
#
# ```json
# query {
#   user_a: user(id: 1) {
#     id
#     name
#     surname
#   }
#   user_b: user(id: 2) {
#     id
#     name
#     surname
#   }
# }
# ```
#
# Srovnejte strukturu dotazů s definicí odpovídajících tříd (`UserGQL` a `GroupGQL`).

# %%
start_api(app=app, port=9992, runNew=False)

# %% [markdown]
# ## GQL with Database

# %% [markdown]
# Předchozí příklad byl bez faktické spolupráce s databází. V této podkapitole je ukázáno, jak navázat datové struktury na databázové záznamy.
#
# Část kapitoly je převzata z textu, který se týká SQLAlchemy a který byste již měli mít zvládnutý.

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.9/site-packages (2.9.3)

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.9/site-packages (1.4.25)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy) (1.1.2)

# %% [markdown]
# ### SQLAlchemy Models

# %% [markdown]
# Modely prezentují struktury uložené v tabulkách. Představují tak proces transformace z výsledku dotazu do struktur jazyka Python a ze struktur jazyka do prvků SQL dotazů.
#
# V SQLAlchemy je zebezpečeno provázání modelů (mimo jiné relace) pomocí dědičnosti, kdy existuje třída, ze které jsou odvozeny všechny modely. Jsou využity specifické funkce jazyka Python k tomu, aby při deklaraci modelů vznikl registr těchto modelů. Tento přístup umožňuje řešit specifické problémy.

# %%
from sqlalchemy.ext.declarative import declarative_base

BaseModel = declarative_base()

# %% [markdown]
# `BaseModel` je třídou, která musí být použita při deklaraci modelů. Všimněte si, že tato třída je návratovou hodnotou funkce. Tuto třídu lze vytvořit různými způsoby, zde si ukazujeme nejčastěji používaný.

# %% [markdown]
# V následující části jsou deklarovány tři modely `UserModel`, `GroupModel` a `GroupTypeModel`. Protože mezi `UserModel` a `GroupModel` je relace M:N, je nutné mít zprostředkující tabulku a tedy i model. Tímto modelem je `UserGroupModel`, který není definovaný jako třída, ale je vytvořen pomocí funkce `Table`.

# %%
import datetime
from sqlalchemy import Column, String, BigInteger, Integer, DateTime, ForeignKey, Sequence, Table
from sqlalchemy.orm import relationship

unitedSequence = Sequence('all_id_seq')

UserGroupModel = Table('users_groups', BaseModel.metadata,
        Column('id', BigInteger, Sequence('all_id_seq'), primary_key=True),
        Column('user_id', ForeignKey('users.id'), primary_key=True),
        Column('group_id', ForeignKey('groups.id'), primary_key=True)
)

class UserModel(BaseModel):
    __tablename__ = 'users'
    
    id = Column(BigInteger, Sequence('all_id_seq'), primary_key=True)
    name = Column(String)
    surname = Column(String)
    email = Column(String)
    
    lastchange = Column(DateTime, default=datetime.datetime.now)
    externalId = Column(BigInteger, index=True)

    groups = relationship('GroupModel', secondary=UserGroupModel, back_populates='users')
        
class GroupModel(BaseModel):
    __tablename__ = 'groups'
    
    id = Column(BigInteger, Sequence('all_id_seq'), primary_key=True)
    name = Column(String)
    
    lastchange = Column(DateTime, default=datetime.datetime.now)
    entryYearId = Column(Integer)

    externalId = Column(String, index=True)

    grouptype_id = Column(ForeignKey('grouptypes.id'))
    grouptype = relationship('GroupTypeModel', back_populates='groups')

    users = relationship('UserModel', secondary=UserGroupModel, back_populates='groups')

class GroupTypeModel(BaseModel):
    __tablename__ = 'grouptypes'
    
    id = Column(BigInteger, Sequence('all_id_seq'), primary_key=True)
    name = Column(String)

    groups = relationship('GroupModel', back_populates='grouptype')

# %% [markdown]
# ### Inicializace struktur v databázi

# %% [markdown]
# Existují dva základní přístupy, které jsou v praxi kombinovány. Jedná se o
#
# - database first
# - code first
#
# V tomto případě využíváme přístup code first, kdy budoucí strukturu tabulek v databázi je definována třídami. Tato definice poslouží k vytvoření struktury databáze a jejich tabulek.

# %%
from sqlalchemy import create_engine

connectionstring = 'postgresql+psycopg2://postgres:example@postgres/newdatabase'
engine = create_engine(connectionstring)

# %%
# BaseModel.metadata.drop_all(engine)
BaseModel.metadata.create_all(engine)

# %% [markdown]
# `drop_all` všechny tabulky odstraní. Pozor, není to prosté a destruktivní odstranění. Pokud dosud definovaná struktura (třídami) neodpovídá struktuře relací v databázi, může dojít k chybě.
#
# `create_all` vytvoří všechny tabulky a relace mezi nimi.

# %% [markdown]
# ### Session

# %% [markdown]
# `session` je entita, s jejíž pomocí jsou realizovány příkazy v databázi (SQL).
#
# V SQLAlchemy se nejdříve vytváří `SessionMaker`, což je callable a jejím voláním se vytváří `session`. `session` se používá na ucelené operace její životnost je omezena právě jen na jednu ucelenou operaci.

# %%
from sqlalchemy.orm import sessionmaker

SessionMaker = sessionmaker(bind=engine)
session = SessionMaker()

# %% [markdown]
# ### CRUD Ops

# %% [markdown]
# Nad daty se provádí čtyři základní operace:
#
# - **C**reate
# - **R**ead
# - **U**pdate
# - **D**elete
#
# Pokud je plánováno nasazení REST API, je vhodné mít tyto operace pro datové entity definované v izolovaných funkcích nebo metodách třídy.
#
# Parametr `db` v následujících funkcích reprezentuje `session` diskutovanou výše.

# %%
def crudUserGet(db: SessionMaker, id: int):
    return db.query(UserModel).filter(UserModel.id==id).first()

def crudUserGetAll(db: SessionMaker, skip: int = 0, limit: int = 100):
    return db.query(UserModel).offset(skip).limit(limit).all()

def crudUserCreate(db: SessionMaker, user):
    userRow = UserModel(name=user.name)
    db.add(userRow)
    db.commit()
    db.refresh(userRow)
    return userRow

def crudUserUpdate(db: SessionMaker, user):
    userToUpdate = db.query(UserModel).filter(UserModel.id==user.id).first()
    userToUpdate.name = user.name if user.name else userToUpdate.name
    db.commit()
    db.refresh(userToUpdate)
    return userToUpdate

# %% [markdown]
# ### GQL Models

# %% [markdown]
# Protože využíváme SQLAlchemy, jsou explicitní resolvery jednoduché.

# %%
import graphene

class UserGQL(graphene.ObjectType):
    """Represents an user. User can be connected to several groups where the user is member. Also the user can play several roles."""
    id = graphene.ID()
    name = graphene.String()
    surname = graphene.String()
    email = graphene.String()
    
    groups = graphene.Field(graphene.List(lambda: GroupGQL))
    
    def resolve_groups(parent, info):
        return parent.groups
        
class GroupTypeGQL(graphene.ObjectType): 
    """"Represents a type of group such as "faculty" or "department". """
    id = graphene.ID()
    name = graphene.String()
    
    groups = graphene.List(lambda: GroupGQL)   
    
    def resolve_groups(parent, info):
        return parent.groups
    
class GroupGQL(graphene.ObjectType):
    """"Represents a group which has several members - users. Group is defined by its type, also it has a parent and children."""
    id = graphene.ID()
    name = graphene.String()
    users = graphene.List(UserGQL)
    
    def resolve_users(parent, info):
        return parent.users

    grouptype = graphene.Field(lambda: GroupTypeGQL)
    
    def resolve_grouptype(parent, info):
        groupTypeId = parent.grouptype_id
        ###
        return parent.grouptype

# %% [markdown]
# ### Query Root

# %% [markdown]
# Resolvery v `QueryGQL` jsou ovšem poněku složitější. Jejich cílem je v příslušné tabulce najít záznam s požadovaným `id`.

# %%
import graphene

class QueryGQL(graphene.ObjectType):
    user = graphene.Field(UserGQL, id = graphene.ID(required = True))
    group = graphene.Field(GroupGQL, id = graphene.ID(required = True))
    grouptype = graphene.Field(GroupTypeGQL, id = graphene.ID(required = True))
    
    def resolve_user(root, info, id):
        session = extractSession(info)
        result = session.query(UserModel).filter(UserModel.id==id).first()
        return result
    
    def resolve_group(root, info, id):
        session = extractSession(info)
        result = session.query(GroupModel).filter(GroupModel.id==id).first()
        return result    
    
    def resolve_grouptype(root, info, id):
        session = extractSession(info)
        result = session.query(GroupTypeModel).filter(GroupTypeModel.id==id).first()
        return result

# %% [markdown]
# ### Session Management

# %% [markdown]
# Protože pracujeme s databází musíme zabezpečit správné ustanovení spojení. Níže uvedená implementace je jedno z možných.

# %%
dbSessionData = {}

def defineStartupAndShutdown(app, SessionMaker):
    @app.on_event("startup")
    async def startup_event():
        session = SessionMaker()
        dbSessionData['session'] = session

    @app.on_event("shutdown")
    def shutdown_event():
        session = dbSessionData.get('session', None)
        if not session is None:
            session.close()

# %% [markdown]
# V kódu dosud chyběla funkce, která v těle resolveru zabezpečí session. Tato funkce je uvedena níže. Session je extrahována z globální proměnné typu dictionary.

# %%
def extractSession(info):
    session = dbSessionData.get('session', None)
    assert not session is None, 'session is not awailable'
    return session

# %% [markdown]
# ### App

# %% [markdown]
# A nakonec finální aplikace. Pozor, je implementováno jen čtení, zápis do databáze pořád chybí.
#
# Po spuštění buňky níže otevřete stránku http://localhost:31102/gql

# %%
#from starlette.graphql import GraphQLApp
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI

graphql_app = GraphQLApp(
    schema=graphene.Schema(query=QueryGQL), 
    on_get=make_graphiql_handler())

app = FastAPI()#root_path='/api')

defineStartupAndShutdown(app, SessionMaker)

app.add_route('/gql/', graphql_app)
start_api(app=app, port=9992, runNew=True)
# Out:
# INFO:     Started server process [2385]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     172.21.0.1:52748 - "GET /gql/ HTTP/1.1" 200 OK
# INFO:     172.21.0.1:52748 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.21.0.1:52748 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     172.21.0.1:52758 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52762) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52786 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52790) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.21.0.1', 52798) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52806 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52810) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52818 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.21.0.1:52822 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52826) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [2385]

# %%
start_api(app=app, port=9992, runNew=False)

# %% [markdown]
# ## GQL with Write (Mutations)

# %% [markdown]
# Mutace (změny) představují mechanismus pro zanesení změn do datových struktur.

# %% [markdown]
# ### Mutations

# %%
import graphene

class CreateUserInput(graphene.InputObjectType):
    name = graphene.String(required=False)
    surname = graphene.String(required=False)
    email = graphene.String(required=False)
    
    def asDict(self):
        return {
            'name': self.name,
            'surname': self.surname,
            'email': self.email
        }
    
class CreateUserGQL(graphene.Mutation):
    class Arguments:
        user = CreateUserInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(UserGQL)
    
    def mutate(parent, info, user):
        session = extractSession(info)
        userDict = user.asDict()
        userRow = UserModel(**userDict)
        session.add(userRow)
        session.commit()
        session.refresh(userRow)
        return CreateUserGQL(ok=True, result=userRow)
    pass

class UpdateUserInput(graphene.InputObjectType):
    id = graphene.ID(required=True)
    name = graphene.String(required=False)
    surname = graphene.String(required=False)
    email = graphene.String(required=False)
    
    def asDict(self):
        return {
            'id': self.id,
            'name': self.name,
            'surname': self.surname,
            'email': self.email
        }
    
class UpdateUserGQL(graphene.Mutation):
    class Arguments:
        user = UpdateUserInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(UserGQL)
    
    def mutate(parent, info, user):
        session = extractSession(info)
        userDict = user.asDict()
        userRow = session.query(UserModel).filter(UserModel.id==user.id).first()
        if 'name' in userDict:
            user.name = userDict['name']
        if 'surname' in userDict:
            user.name = userDict['surname']
        if 'email' in userDict:
            user.name = userDict['email']
        session.commit()
        session.refresh(userRow)
        return CreateUserGQL(ok=True, result=userRow)
    pass

# %%
class Mutations(graphene.ObjectType):
    create_user = CreateUserGQL.Field()
    update_user = UpdateUserGQL.Field()

# %% [markdown]
# ### App

# %% [markdown]
# A nakonec finální aplikace, tentokrát s možností vkládat a upravovat záznamy o uživatelích.

# %%
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI

graphql_app = GraphQLApp(
    schema=graphene.Schema(query=QueryGQL, mutation=Mutations), 
    on_get=make_graphiql_handler())

app = FastAPI()#root_path='/api')

defineStartupAndShutdown(app, SessionMaker)

app.add_route('/gql/', graphql_app)
start_api(app=app, port=9992, runNew=True)
# Out:
# INFO:     Started server process [2452]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     172.21.0.1:52888 - "GET /gql/ HTTP/1.1" 200 OK
# INFO:     172.21.0.1:52888 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52892) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52902 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52908) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52916 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52936) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     ('172.21.0.1', 52946) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52954 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52960) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     172.21.0.1:52968 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     ('172.21.0.1', 52972) - "WebSocket /gql/" 403
# INFO:     connection failed (403 Forbidden)
# INFO:     connection closed
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [2452]

# %%
start_api(app=app, port=9992, runNew=False)

# %% [markdown]
# ## GraphQL composition

# %% [markdown]
# Jednou z možností využití GraphQL je zastřešení existujících API. V příkladu níže jsou definovány dva servery GraphQL, které jsou zastřešeny (zprostředkovány) pomocí třetího serveru. Principiálně lze takto zastřešit i servery jiného typu než GraphQL (např. REST API).

# %% [markdown]
# ### Server A

# %% [markdown]
# Definice datových struktur pro server A, který poskytuje informace o entitách user.

# %%
import random

def randomUser():
    surNames = [
        'Novák', 'Nováková', 'Svobodová', 'Svoboda', 'Novotná',
        'Novotný', 'Dvořáková', 'Dvořák', 'Černá', 'Černý', 
        'Procházková', 'Procházka', 'Kučerová', 'Kučera', 'Veselá',
        'Veselý', 'Horáková', 'Krejčí', 'Horák', 'Němcová', 
        'Marková', 'Němec', 'Pokorná', 'Pospíšilová','Marek'
    ]

    names = [
        'Jiří', 'Jan', 'Petr', 'Jana', 'Marie', 'Josef',
        'Pavel', 'Martin', 'Tomáš', 'Jaroslav', 'Eva',
        'Miroslav', 'Hana', 'Anna', 'Zdeněk', 'Václav',
        'Michal', 'František', 'Lenka', 'Kateřina',
        'Lucie', 'Jakub', 'Milan', 'Věra', 'Alena'
    ]

    name1 = random.choice(names)
    name2 = random.choice(names)
    name3 = random.choice(surNames)
    return {'name': f'{name1} {name2}', 'surname': f'{name3}', 'email': f'{name1}.{name2}.{name3}@university.world', 'valid': True}

userTable
userTable = dict(((f'{id}', randomUser()) for id in range(10)))
print(userTable)
# Out:
# {'0': {'name': 'Lucie Jan', 'surname': 'Kučerová', 'email': 'Lucie.Jan.Kučerová@university.world', 'valid': True}, '1': {'name': 'Jaroslav Lucie', 'surname': 'Horák', 'email': 'Jaroslav.Lucie.Horák@university.world', 'valid': True}, '2': {'name': 'Alena Petr', 'surname': 'Marková', 'email': 'Alena.Petr.Marková@university.world', 'valid': True}, '3': {'name': 'Alena Jaroslav', 'surname': 'Marek', 'email': 'Alena.Jaroslav.Marek@university.world', 'valid': True}, '4': {'name': 'Jaroslav Lucie', 'surname': 'Svoboda', 'email': 'Jaroslav.Lucie.Svoboda@university.world', 'valid': True}, '5': {'name': 'Kateřina Eva', 'surname': 'Novotná', 'email': 'Kateřina.Eva.Novotná@university.world', 'valid': True}, '6': {'name': 'Pavel Jaroslav', 'surname': 'Veselá', 'email': 'Pavel.Jaroslav.Veselá@university.world', 'valid': True}, '7': {'name': 'Petr Josef', 'surname': 'Novotná', 'email': 'Petr.Josef.Novotná@university.world', 'valid': True}, '8': {'name': 'Michal František', 'surname': 'Procházka', 'email': 'Michal.František.Procházka@university.world', 'valid': True}, '9': {'name': 'Eva Zdeněk', 'surname': 'Němcová', 'email': 'Eva.Zdeněk.Němcová@university.world', 'valid': True}}

# %% [markdown]
# Graphene model

# %%
import graphene

class UserAGQL(graphene.ObjectType):
    """Represents an user."""
    id = graphene.ID()
    name = graphene.String()
    surname = graphene.String()
    email = graphene.String()

# %% [markdown]
# Graphene query root

# %%
class QueryAGQL(graphene.ObjectType):
    user = graphene.Field(UserAGQL, id = graphene.ID(required = True))

    def resolve_user(root, info, id):
        result = userTable.get(id, None)
        if result is None:
            return None
        return {**result, 'id': id}

# %% [markdown]
# Spuštění serveru A

# %%
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI

graphql_appA = GraphQLApp(
    schema=graphene.Schema(query=QueryAGQL), 
    on_get=make_graphiql_handler())

appA = FastAPI()#root_path='/api')

appA.add_route('/gql/', graphql_appA)
start_api(app=appA, port=9992, runNew=True)
# Out:
# INFO:     Started server process [452]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     127.0.0.1:38722 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38722 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38754 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38754 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38788 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38788 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38830 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38830 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38880 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38880 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38930 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:38930 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [452]

# %% [markdown]
# Test funkčnosti serveru A

# %%
import requests

def resolve_user(id):
    query = f"""query {{
        user(id: {id}) {{
            id
            name
            surname
            email
        }}
    }}"""
    payload = {'query': query}
    r = requests.post("http://localhost:9992/gql", json=payload)
    return r.json()

print(resolve_user(1))
# Out:
# {'data': {'user': {'id': '1', 'name': 'Jaroslav Lucie', 'surname': 'Horák', 'email': 'Jaroslav.Lucie.Horák@university.world'}}}

# %% [markdown]
# ### Server B

# %% [markdown]
# Definice datových struktur pro server B

# %%
import random

def randomGroup():
    valuesA = ['K', 'V', 'N']
    valuesB = ['A', 'E', 'I', 'O', 'U']
    valuesC = ['1', '2', '3', '4', '5']

    return {'name': f'{random.choice(valuesA)}{random.choice(valuesB)}{random.choice(valuesC)}', 'valid': True}

groupTable = dict(((f'{id}', randomGroup()) for id in range(10)))
print(groupTable)
# Out:
# {'0': {'name': 'VO4', 'valid': True}, '1': {'name': 'VO3', 'valid': True}, '2': {'name': 'VO5', 'valid': True}, '3': {'name': 'NU3', 'valid': True}, '4': {'name': 'VO2', 'valid': True}, '5': {'name': 'KU5', 'valid': True}, '6': {'name': 'NE5', 'valid': True}, '7': {'name': 'KA5', 'valid': True}, '8': {'name': 'KU2', 'valid': True}, '9': {'name': 'VU5', 'valid': True}}

# %% [markdown]
# Model pro GraphQL

# %%
import graphene

class GroupBGQL(graphene.ObjectType):
    """Represents an group. """
    id = graphene.ID()
    name = graphene.String()

# %% [markdown]
# Root pro GraphQL

# %%
class QueryBGQL(graphene.ObjectType):
    group = graphene.Field(GroupBGQL, id = graphene.ID(required = True))

    def resolve_group(root, info, id):
        result = groupTable.get(id, None)
        if result is None:
            return None
        return {**result, 'id': id}

# %% [markdown]
# Spuštění serveru B

# %%
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI

graphql_appB = GraphQLApp(
    schema=graphene.Schema(query=QueryBGQL), 
    on_get=make_graphiql_handler())

appB = FastAPI()#root_path='/api')

appB.add_route('/gql/', graphql_appB)
start_api(app=appB, port=9993, runNew=True)
# Out:
# INFO:     Started server process [469]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9993 (Press CTRL+C to quit)
# INFO:     127.0.0.1:39296 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39296 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39320 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39320 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39358 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39358 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39404 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39404 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39454 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39454 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39496 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:39496 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [469]

# %% [markdown]
# Test funkčnosti serveru B

# %%
import requests

def resolve_group(id):
    query = f"""query {{
        group(id: {id}) {{
            id
            name
        }}
    }}"""
    payload = {'query': query}
    r = requests.post("http://localhost:9993/gql", json=payload)
    return r.json()

print(resolve_group(1))
# Out:
# {'data': {'group': {'id': '1', 'name': 'VO3'}}}

# %% [markdown]
# ### Composed Server

# %% [markdown]
# GraphQL server, který zastřešuje jiná API (v tomto případě dvě a obě typu GraphQL), musí mít definovány adekvátní modely. V tomto případě vycházíme z modelů dříve definovaných a vytváříme jen jiné root query. Pro resolvery jsou využity funkce, s jejichž pomocí byla testována funkčnost serverů A a B.

# %%
class QueryCGQL(graphene.ObjectType):
    user = graphene.Field(UserAGQL, id = graphene.ID(required = True))
    group = graphene.Field(GroupBGQL, id = graphene.ID(required = True))

    def resolve_user(root, info, id):
        serverResponse = resolve_user(id)
        result = serverResponse['data']['user']
        return {**result, 'id': id}
    
    def resolve_group(root, info, id):
        serverResponse = resolve_group(id)
        result = serverResponse['data']['group']
        return {**result, 'id': id}

# %% [markdown]
# Vlastní spuštění zastřešujícího serveru

# %%
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

import graphene
from fastapi import FastAPI

graphql_appC = GraphQLApp(
    schema=graphene.Schema(query=QueryCGQL), 
    on_get=make_graphiql_handler())

appC = FastAPI()#root_path='/api')

appC.add_route('/gql/', graphql_appC)
start_api(app=appC, port=9994, runNew=True)
# Out:
# INFO:     Started server process [658]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9994 (Press CTRL+C to quit)
# INFO:     127.0.0.1:33312 - "POST /gql HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:33312 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [658]

# %% [markdown]
# Test funkčnosti

# %%
import requests

query = """query {
    user(id: 1) {
        id
        name
        surname
        email
    }

    group(id: 1) {
        id
        name
    }
}"""
payload = {'query': query}
r = requests.post("http://localhost:9994/gql", json=payload)
result = r.json()

print(result)
# Out:
# {'data': {'user': {'id': '1', 'name': 'Jaroslav Lucie', 'surname': 'Horák', 'email': 'Jaroslav.Lucie.Horák@university.world'}, 'group': {'id': '1', 'name': 'VO3'}}}

# %% [markdown]
# ### Zastavení serverů

# %%
start_api(app=appC, port=9994, runNew=False)

# %%
start_api(app=appA, port=9992, runNew=False)
start_api(app=appB, port=9993, runNew=False)

# %% [markdown]
# ### Apollo server gateway

# %% [markdown]
# xmorse/apollo-federation-gateway
#
# https://github.com/remorses/apollo-federation-gateway
#
# Ariadne / Python https://ariadnegraphql.org/docs/apollo-federation
#
# https://github.com/preply/graphene-federation
